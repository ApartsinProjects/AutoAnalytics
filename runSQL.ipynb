# %%
from mngDB import MngDB
user_uid='d2803e43-2d39-4586-8b70-d49052523902'
org_uid='57b5e8a2-5613-49ca-b1c2-1d2a9a4d28e1'

# %%
from dataSource import DataSource
ds=DataSource().connect_str("mysql+pymysql://taskanalytics:leningrad@localhost/cdeschool")
# Out:
# 2024-08-15 09:44:54,637 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-08-15 09:44:54,638 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-08-15 09:44:54,639 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-08-15 09:44:54,639 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-08-15 09:44:54,640 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-08-15 09:44:54,641 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
from sqlalchemy import inspect

# %%
engine_insp=inspect(ds.engine)

# %%
engine_insp.get_foreign_keys("frpm")
# Out:
# [{'name': 'frpm_ibfk_1',
#   'constrained_columns': ['CDSCode'],
#   'referred_schema': None,
#   'referred_table': 'schools',
#   'referred_columns': ['CDSCode'],
#   'options': {}}]

# %%
engine_insp.get_pk_constraint("frpm")
# Out:
# {'constrained_columns': ['CDSCode'], 'name': None}
