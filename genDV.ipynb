# %%
import logging,sys


# %reload_ext autoreload
# %autoreload 2

# %%
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# %%
insurance_user_info={"user_name":"AccMichal","user_role":"insurance analyst"}

insurance_org_info={"org_name":"AcmeInsurance",
          "org_descr":"road accident insurance company",
          "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/accidents",
          "org_data_app":"government road accident tracking system",
          "data_fmt":"MySQL database"}

bank_user_info={"user_name":"AccPeter","user_role":"loan approval officer"}
bank_org_info={"org_name":"AcmeBank",
          "org_descr":"bank giving loans to his customers",
          "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/credit",
          "org_data_app":"loan tracking system",
          "data_fmt":"MySQL database"}

# %%
from taGenie import TAGenie
tg=TAGenie().generate_analytics(bank_user_info,bank_org_info)
# Out:
# INFO:root:connecting to taskanalytics
# INFO:root:find objs in orgs by org_name='AcmeBank'
# INFO:root:fetching select * from orgs where org_name='AcmeBank'
# INFO:root:executing update orgs SET org_name='AcmeBank',org_descr='bank giving loans to his customers',org_conn_str='mysql+pymysql://taskanalytics:leningrad@localhost/credit',org_data_app='loan tracking system',data_fmt='MySQL database' where org_uid='ff6b2be9-47be-49c8-9317-e2b29d237f2c'
# INFO:root:find objs in users by user_name='AccPeter'
# INFO:root:fetching select * from users where user_name='AccPeter'
# INFO:root:executing update users SET user_name='AccPeter',user_role='loan approval officer',user_org_uid='ff6b2be9-47be-49c8-9317-e2b29d237f2c' where user_uid='35c3c107-c4a3-4260-8f12-7e41b3614070'
# INFO:root:connecting to taskanalytics
# INFO:root:fetching select * from tables where table_org_uid='ff6b2be9-47be-49c8-9317-e2b29d237f2c'
# ...
