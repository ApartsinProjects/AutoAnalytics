# %%
import logging,sys

# %reload_ext autoreload
# %autoreload 2

# %%
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# %%
use_cases={    
    "insurance":{
        "user":{
                "user_name":"Michael",
                "user_role":"Actuarial analyst"},
        "org": {
                "org_name":"AcmeInsurance",
                "org_descr":"Large car insurance company",
                "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/accidents",
                "org_data_app":"Government road accident tracking system",
                "data_fmt":"MySQL database"}},
    
    "police":{
        "user":{
                "user_name":"Jack",
                "user_role":"Police Safety Office"},
        "org": {
                "org_name":"Dallas Police Department",
                "org_descr":"Metro Police Department",
                "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/dallas",
                "org_data_app":"Officer involved shooting",
                "data_fmt":"MySQL database"}},
    
    "manufacturing__":{
        "user":{
                "user_name":"Donald",
                "user_role":"Supply Chain Manager"},
        "org": {
                "org_name":"AdventureWorks Manufacturing",
                "org_descr":"Bicycle Manufacturing Plant",
                "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/adventureworks2014",
                "org_data_app":"ERP system",
                "data_fmt":"MySQL database"}},
    
    "loans":{
        "user":{
                "user_name":"Anna",
                "user_role":"Loan Officer"},
        "org": {
                "org_name":"GoldBank",
                "org_descr":"Large retailer bank",
                "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/financials_std",
                "org_data_app":"Loan Management System",
                "data_fmt":"MySQL database"}},
    
    "hospital":{
             "user":{
                "user_name":"Ella",
                "user_role":"Chief Medical Officer"},
        "org": {
                "org_name":"AcmeHospital",
                "org_descr":"Large hospital",
                "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/fnhk",
                "org_data_app":"Treatments and medications",
                "data_fmt":"MySQL database"}},
    
    "sales__":{
             "user":{
                "user_name":"Rick",
                "user_role":"Sales Management"},
        "org": {
                "org_name":"Great Outdoors",
                "org_descr":"Outdoor equipment sales",
                "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/gosales",
                "org_data_app":"Sales records database",
                "data_fmt":"MySQL database"}},
    
    "bank":{
        "user":{
                "user_name":"Peter",
                "user_role":"Credit product manager"},
        "org": {
            "org_name":"AcmeBank",
            "org_descr":"Large retailer bank",
            "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/credit",
            "org_data_app":"Loan tracking system",
            "data_fmt":"MySQL database"}},
    
    "education":{
        "user":{
                "user_name":"Alex",
                "user_role":"Educational polices analyst"},
        "org": {
            "org_name":"California CDE",
            "org_descr":"Government education department",
            "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/cdeschool",
            "org_data_app":"schools management system",
            "data_fmt":"MySQL database"}},
    
    "travel":{
        "user":{
                "user_name":"Bob",
                "user_role":"Travel agent"},
        "org": {
            "org_name":"AcmeBizTravel",
            "org_descr":"Corporate travel agency",
            "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/airlines",
            "org_data_app":"DoT historical data on airlines",
            "data_fmt":"MySQL database"}},
    
    "pharma":{
        "user":{
                "user_name":"Joan",
                "user_role":"Drug Designer"},
        "org": {
            "org_name":"AcmePharma",
            "org_descr":"atherosclerosis Treatment Pharma",
            "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/atherosclrosis",
            "org_data_app":"Atherosclerosis study data",
            "data_fmt":"MySQL database"}},
    
     "auto":{
        "user":{
                "user_name":"Richard",
                "user_role":"Car salesman"},
        "org": {
            "org_name":"ClassicModel",
            "org_descr":"Dealership for classic model cars",
            "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/classicmodel",
            "org_data_app":"Inventory and sales data",
            "data_fmt":"MySQL database"}},
     
     "grants":{
        "user":{
                "user_name":"Michael",
                "user_role":"Research Grant Applicant"},
        "org": {
            "org_name":"AcmeUniversity",
            "org_descr":"Research Lab",
            "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/grants",
            "org_data_app":"Historical Grant Data",
            "data_fmt":"MySQL database"}},
}

# %%
from taGenie import TAGenie
all_steps=["create","schema","tasks","kpis","sql","test","report","debug","report","visuals","insights"]
ucs=[]

def run_all(ucs=use_cases.keys(),steps=all_steps):
    for k in ucs: 
        ta=TAGenie()
        ta.process(use_cases[k],steps=steps)

# %%
run_all(["travel","pharma","auto","grants"])
# Out:
# INFO:root:
# ============================ starting provisioning of user and his org=======================================================
#
# INFO:root:connecting to taskanalytics
# INFO:root:find objs in orgs by org_name='AcmeBizTravel'
# INFO:root:fetch select * from orgs where org_name='AcmeBizTravel' with nrows:1
# INFO:root:executing update orgs SET org_name='AcmeBizTravel',org_descr='Corporate travel agency',org_conn_str='mysql+pymysql://taskanalytics:leningrad@localhost/airlines',org_data_app='DoT historical data on airlines',data_fmt='MySQL database' where org_uid='d7d2bb04-2e7f-433f-8f51-982b631377da'
# INFO:root:find objs in users by user_name='Bob'
# INFO:root:fetch select * from users where user_name='Bob' with nrows:1
# INFO:root:executing update users SET user_name='Bob',user_role='Travel agent',user_org_uid='d7d2bb04-2e7f-433f-8f51-982b631377da' where user_uid='ccbb5058-c2f8-4ac7-bc85-a0c47172baba'
# INFO:root:connecting to taskanalytics
# INFO:root:find obj in users by ccbb5058-c2f8-4ac7-bc85-a0c47172baba
# INFO:root:find objs in users by user_uid='ccbb5058-c2f8-4ac7-bc85-a0c47172baba'
# INFO:root:fetch select * from users where user_uid='ccbb5058-c2f8-4ac7-bc85-a0c47172baba' with nrows:1
# INFO:root:
# ============================ fetching and annotating DB scheme=======================================================
#
# INFO:root:connecting to taskanalytics
# INFO:root:fetch select * from tables where table_org_uid='d7d2bb04-2e7f-433f-8f51-982b631377da' with nrows:19
# INFO:root:executing delete from cols where col_table_uid='9e69385f-f45c-486e-b0b5-cbc39006efbf'
# INFO:root:executing delete from cols where col_table_uid='58df3593-d456-4b5b-8e5e-8b7468ab9de3'
# INFO:root:executing delete from cols where col_table_uid='665d1e69-e48c-4bab-8113-3905914248a7'
# INFO:root:executing delete from cols where col_table_uid='d4225c53-d255-4759-a9d5-e1d9d51d01f2'
# INFO:root:executing delete from cols where col_table_uid='16702e7b-af8c-4ca1-bac6-c807ec7bc968'
# INFO:root:executing delete from cols where col_table_uid='e8ec0c88-2dca-4e9d-b382-07df4436db62'
# INFO:root:executing delete from cols where col_table_uid='aed0b9b0-2eea-49a0-b5fa-f967cc429009'
# INFO:root:executing delete from cols where col_table_uid='4a7dfb68-ac3b-47c5-a6f4-20efb4a906a7'
# INFO:root:executing delete from cols where col_table_uid='8fd56e94-510e-413f-902d-c4db411d4269'
# INFO:root:executing delete from cols where col_table_uid='260577df-6a4b-4592-8d34-7b92fa942d98'
# INFO:root:executing delete from cols where col_table_uid='a6438b6c-c1bd-4483-9aee-bf1118ea6daf'
# INFO:root:executing delete from cols where col_table_uid='fd5a2748-9547-411f-bf68-1d94e1229dde'
# INFO:root:executing delete from cols where col_table_uid='8c3bcff6-b59d-4666-945b-36243dac8e47'
# INFO:root:executing delete from cols where col_table_uid='6d611caa-2138-49e4-8624-db989cb02304'
# INFO:root:executing delete from cols where col_table_uid='a821d270-803b-4e31-ae57-434cc76f1ffe'
# INFO:root:executing delete from cols where col_table_uid='76318ee5-5f53-40fe-afd9-54f3a9cd58e0'
# INFO:root:executing delete from cols where col_table_uid='14a8e0f5-b65a-4329-be2d-557fc924d360'
# INFO:root:executing delete from cols where col_table_uid='ed9eaeba-fada-4807-9647-20c6d204fb46'
# INFO:root:executing delete from cols where col_table_uid='aacc7af9-23e1-4b1d-9566-77394f30e21c'
# INFO:root:executing delete from tables where table_org_uid='d7d2bb04-2e7f-433f-8f51-982b631377da'
# INFO:root:find obj in orgs by d7d2bb04-2e7f-433f-8f51-982b631377da
# INFO:root:find objs in orgs by org_uid='d7d2bb04-2e7f-433f-8f51-982b631377da'
# INFO:root:fetch select * from orgs where org_uid='d7d2bb04-2e7f-433f-8f51-982b631377da' with nrows:1
# 2024-08-18 19:10:53,174 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# INFO:sqlalchemy.engine.Engine:SELECT DATABASE()
# 2024-08-18 19:10:53,190 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,192 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# INFO:sqlalchemy.engine.Engine:SELECT @@sql_mode
# 2024-08-18 19:10:53,192 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,192 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# INFO:sqlalchemy.engine.Engine:SELECT @@lower_case_table_names
# 2024-08-18 19:10:53,192 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,208 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,209 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `airlines`
# INFO:sqlalchemy.engine.Engine:SHOW FULL TABLES FROM `airlines`
# 2024-08-18 19:10:53,210 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,250 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,250 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,250 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airline_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airline_id`
# 2024-08-18 19:10:53,250 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,261 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,263 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,264 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airline_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airline_id`
# 2024-08-18 19:10:53,264 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,265 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,267 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,267 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airport`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airport`
# 2024-08-18 19:10:53,267 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,267 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,267 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,267 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airport`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airport`
# 2024-08-18 19:10:53,273 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,275 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,277 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,278 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airport_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airport_id`
# 2024-08-18 19:10:53,280 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,280 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,280 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,280 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airport_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airport_id`
# 2024-08-18 19:10:53,280 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,280 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,280 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,280 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airport_seq_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airport_seq_id`
# 2024-08-18 19:10:53,280 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,290 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,292 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,292 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airport_seq_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airport_seq_id`
# 2024-08-18 19:10:53,294 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,295 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,295 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,295 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_cancellation`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_cancellation`
# 2024-08-18 19:10:53,295 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,295 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,295 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,295 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_cancellation`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_cancellation`
# 2024-08-18 19:10:53,295 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,295 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,307 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,307 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_city_market_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_city_market_id`
# 2024-08-18 19:10:53,308 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,310 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,312 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,312 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_city_market_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_city_market_id`
# 2024-08-18 19:10:53,312 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,312 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,312 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,312 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_deparrblk`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_deparrblk`
# 2024-08-18 19:10:53,312 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,312 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,312 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,312 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_deparrblk`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_deparrblk`
# 2024-08-18 19:10:53,324 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,325 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,327 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,328 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_distance_group_250`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_distance_group_250`
# 2024-08-18 19:10:53,329 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,331 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,334 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,335 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_distance_group_250`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_distance_group_250`
# 2024-08-18 19:10:53,336 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,338 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,340 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,340 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_diversions`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_diversions`
# 2024-08-18 19:10:53,342 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,345 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,346 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,347 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_diversions`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_diversions`
# 2024-08-18 19:10:53,348 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,350 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,351 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,352 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_months`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_months`
# 2024-08-18 19:10:53,353 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,355 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,356 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,357 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_months`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_months`
# 2024-08-18 19:10:53,358 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,359 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,374 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,375 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_ontime_delay_groups`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_ontime_delay_groups`
# 2024-08-18 19:10:53,376 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,376 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,376 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,376 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_ontime_delay_groups`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_ontime_delay_groups`
# 2024-08-18 19:10:53,376 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,376 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,376 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,376 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_quarters`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_quarters`
# 2024-08-18 19:10:53,376 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,390 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,391 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_quarters`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_quarters`
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_state_abr_aviation`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_state_abr_aviation`
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_state_abr_aviation`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_state_abr_aviation`
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,393 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,407 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_state_fips`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_state_fips`
# 2024-08-18 19:10:53,408 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,410 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,411 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,412 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_state_fips`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_state_fips`
# 2024-08-18 19:10:53,414 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,415 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,417 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,418 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_unique_carriers`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_unique_carriers`
# 2024-08-18 19:10:53,418 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,420 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,421 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,422 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_unique_carriers`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_unique_carriers`
# 2024-08-18 19:10:53,423 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,424 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,428 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,429 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_weekdays`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_weekdays`
# 2024-08-18 19:10:53,430 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,431 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,431 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,431 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_weekdays`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_weekdays`
# 2024-08-18 19:10:53,431 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,431 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,431 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,431 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_world_area_codes`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_world_area_codes`
# 2024-08-18 19:10:53,440 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,442 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,444 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,445 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_world_area_codes`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_world_area_codes`
# 2024-08-18 19:10:53,446 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,448 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,449 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,450 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_yesno_resp`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_yesno_resp`
# 2024-08-18 19:10:53,451 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,453 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,454 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,455 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_yesno_resp`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_yesno_resp`
# 2024-08-18 19:10:53,455 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,457 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,459 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,460 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `on_time_on_time_performance_2016_1`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `on_time_on_time_performance_2016_1`
# 2024-08-18 19:10:53,461 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,465 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,465 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,465 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `on_time_on_time_performance_2016_1`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `on_time_on_time_performance_2016_1`
# 2024-08-18 19:10:53,465 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,465 INFO sqlalchemy.engine.Engine
#                     select table_schema, table_name, column_name
#                     from information_schema.columns
#                     where (table_schema, table_name, lower(column_name)) in
#                     ((%(table_data_1_1)s, %(table_data_1_2)s, %(table_data_1_3)s), (%(table_data_2_1)s, %(table_data_2_2)s, %(table_data_2_3)s), (%(table_data_3_1)s, %(table_data_3_2)s, %(table_data_3_3)s), (%(table_data_4_1)s, %(table_data_4_2)s, %(table_data_4_3)s), (%(table_data_5_1)s, %(table_data_5_2)s, %(table_data_5_3)s), (%(table_data_6_1)s, %(table_data_6_2)s, %(table_data_6_3)s), (%(table_data_7_1)s, %(table_data_7_2)s, %(table_data_7_3)s), (%(table_data_8_1)s, %(table_data_8_2)s, %(table_data_8_3)s), (%(table_data_9_1)s, %(table_data_9_2)s, %(table_data_9_3)s), (%(table_data_10_1)s, %(table_data_10_2)s, %(table_data_10_3)s), (%(table_data_11_1)s, %(table_data_11_2)s, %(table_data_11_3)s), (%(table_data_12_1)s, %(table_data_12_2)s, %(table_data_12_3)s), (%(table_data_13_1)s, %(table_data_13_2)s, %(table_data_13_3)s), (%(table_data_14_1)s, %(table_data_14_2)s, %(table_data_14_3)s), (%(table_data_15_1)s, %(table_data_15_2)s, %(table_data_15_3)s), (%(table_data_16_1)s, %(table_data_16_2)s, %(table_data_16_3)s), (%(table_data_17_1)s, %(table_data_17_2)s, %(table_data_17_3)s), (%(table_data_18_1)s, %(table_data_18_2)s, %(table_data_18_3)s), (%(table_data_19_1)s, %(table_data_19_2)s, %(table_data_19_3)s), (%(table_data_20_1)s, %(table_data_20_2)s, %(table_data_20_3)s), (%
d7d2bb04-2e7f-433f-8f51-982b631377da','{"constrained_columns": ["Code"], "name": null}','[]','f32c2943-cf64-476d-831c-acd85dff7d6f'),('l_yesno_resp','d7d2bb04-2e7f-433f-8f51-982b631377da','{"constrained_columns": ["Code"], "name": null}','[]','22bfab2d-b111-4c2b-a4fa-71946fee0e18'),('on_time_on_time_performance_2016_1','d7d2bb04-2e7f-433f-8f51-982b631377da','{"name": null, "constrained_columns": []}','[{"name": "On_Time_On_Time_Performance_2016_1_AirlineID_fkey", "constrained_columns": ["AirlineID"], "referred_schema": null, "referred_table": "l_airline_id", "referred_columns": ["Code"], "options": {"onupdate": "CASCADE", "ondelete": "CASCADE"}}, {"name": "On_Time_On_Time_Performance_2016_1_ArrDel15_fkey", "constrained_columns": ["ArrDel15"], "referred_schema": null, "referred_table": "l_yesno_resp", "referred_columns": ["Code"], "options": {"onupdate": "CASCADE", "ondelete": "CASCADE"}}, {"name": "On_Time_On_Time_Performance_2016_1_ArrivalDelayGroups_fkey", "constrained_columns": ["ArrivalDelayGroups"], "referred_schema": null, "referred_table": "l_ontime_delay_groups", "referred_columns": ["Code"], "options": {"onupdate": "CASCADE", "ondelete": "CASCADE"}}, {"name": "On_Time_On_Time_Performance_2016_1_CancellationCode_fkey", "constrained_columns": ["CancellationCode"], "referred_schema": null, "referred_table": "l_cancellation", "referred_columns": ["Code"], "options": {"onupdate": "CASCADE", "ondelete": "CASCADE"}}, ...
# 2024-08-18 19:10:53,561 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,561 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airline_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airline_id`
# 2024-08-18 19:10:53,561 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,561 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,577 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,577 INFO sqlalchemy.engine.Engine select * from `l_airline_id` LIMIT 3
# INFO:sqlalchemy.engine.Engine:select * from `l_airline_id` LIMIT 3
# 2024-08-18 19:10:53,577 INFO sqlalchemy.engine.Engine [generated in 0.00193s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00193s] {}
# [{'Code': 19031, 'Description': 'Mackey International Inc.: MAC'}, {'Code': 19032, 'Description': 'Munz Northern Airlines Inc.: XY'}, {'Code': 19033, 'Description': 'Cochise Airlines Inc.: COC'}]
# [{'Code': 19031, 'Description': 'Mackey International Inc.: MAC'}, {'Code': 19032, 'Description': 'Munz Northern Airlines Inc.: XY'}, {'Code': 19033, 'Description': 'Cochise Airlines Inc.: COC'}]
# INFO:root:executing insert into cols (col_name,col_type,col_table_uid,col_comment,col_sample_vals,col_uid) values ('code','INTEGER','9addbab0-f38a-4a8d-ac2a-f27a2e4b3584','None','19031,19032,19033','87ab7d83-e910-40ea-b69e-d4a4749b1562'),('description','VARCHAR(255)','9addbab0-f38a-4a8d-ac2a-f27a2e4b3584','None','Mackey International Inc.: MAC,Munz Northern Airlines Inc.: XY,Cochise Airlines Inc.: COC','58bf4ddc-c995-4095-a50b-336871f9c6c6')
# 2024-08-18 19:10:53,584 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,590 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airport`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airport`
# 2024-08-18 19:10:53,592 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,594 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,596 INFO sqlalchemy.engine.Engine select * from `l_airport` LIMIT 3
# INFO:sqlalchemy.engine.Engine:select * from `l_airport` LIMIT 3
# 2024-08-18 19:10:53,596 INFO sqlalchemy.engine.Engine [generated in 0.00093s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00093s] {}
# [{'Code': '01A', 'Description': 'Afognak Lake, AK: Afognak Lake Airport'}, {'Code': '03A', 'Description': 'Granite Mountain, AK: Bear Creek Mining Strip'}, {'Code': '04A', 'Description': 'Lik, AK: Lik Mining Camp'}]
# [{'Code': '01A', 'Description': 'Afognak Lake, AK: Afognak Lake Airport'}, {'Code': '03A', 'Description': 'Granite Mountain, AK: Bear Creek Mining Strip'}, {'Code': '04A', 'Description': 'Lik, AK: Lik Mining Camp'}]
# INFO:root:executing insert into cols (col_name,col_type,col_table_uid,col_comment,col_sample_vals,col_uid) values ('code','CHAR(3)','8476590e-a868-4c5e-9463-b70bd28bddec','None','01A,03A,04A','973c84db-cef6-4ae5-9c86-7499905897b5'),('description','VARCHAR(255)','8476590e-a868-4c5e-9463-b70bd28bddec','None','Afognak Lake, AK: Afognak Lake Airport,Granite Mountain, AK: Bear Creek Mining Strip,Lik, AK: Lik Mining Camp','8396b136-d27a-43c4-8c5b-46dce7ecbd3f')
# 2024-08-18 19:10:53,596 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,596 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airport_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airport_id`
# 2024-08-18 19:10:53,596 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,596 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,596 INFO sqlalchemy.engine.Engine select * from `l_airport_id` LIMIT 3
# INFO:sqlalchemy.engine.Engine:select * from `l_airport_id` LIMIT 3
# 2024-08-18 19:10:53,596 INFO sqlalchemy.engine.Engine [generated in 0.00083s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00083s] {}
# [{'Code': 10001, 'Description': 'Afognak Lake, AK: Afognak Lake Airport'}, {'Code': 10003, 'Description': 'Granite Mountain, AK: Bear Creek Mining Strip'}, {'Code': 10004, 'Description': 'Lik, AK: Lik Mining Camp'}]
# [{'Code': 10001, 'Description': 'Afognak Lake, AK: Afognak Lake Airport'}, {'Code': 10003, 'Description': 'Granite Mountain, AK: Bear Creek Mining Strip'}, {'Code': 10004, 'Description': 'Lik, AK: Lik Mining Camp'}]
# INFO:root:executing insert into cols (col_name,col_type,col_table_uid,col_comment,col_sample_vals,col_uid) values ('code','INTEGER','c83902d9-d1c1-4ae1-82e5-8d346353c9bc','None','10001,10003,10004','47f02aef-41dc-47b9-9df2-7201497c66dc'),('description','VARCHAR(255)','c83902d9-d1c1-4ae1-82e5-8d346353c9bc','None','Afognak Lake, AK: Afognak Lake Airport,Granite Mountain, AK: Bear Creek Mining Strip,Lik, AK: Lik Mining Camp','e358851e-5be1-4782-b331-2b3eb6b93d3c')
# 2024-08-18 19:10:53,609 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,609 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_airport_seq_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_airport_seq_id`
# 2024-08-18 19:10:53,609 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,609 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,609 INFO sqlalchemy.engine.Engine select * from `l_airport_seq_id` LIMIT 3
# INFO:sqlalchemy.engine.Engine:select * from `l_airport_seq_id` LIMIT 3
# 2024-08-18 19:10:53,609 INFO sqlalchemy.engine.Engine [generated in 0.00082s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00082s] {}
# [{'Code': 1000101, 'Description': 'Afognak Lake, AK: Afognak Lake Airport'}, {'Code': 1000301, 'Description': 'Granite Mountain, AK: Bear Creek Mining Strip'}, {'Code': 1000401, 'Description': 'Lik, AK: Lik Mining Camp'}]
# [{'Code': 1000101, 'Description': 'Afognak Lake, AK: Afognak Lake Airport'}, {'Code': 1000301, 'Description': 'Granite Mountain, AK: Bear Creek Mining Strip'}, {'Code': 1000401, 'Description': 'Lik, AK: Lik Mining Camp'}]
# INFO:root:executing insert into cols (col_name,col_type,col_table_uid,col_comment,col_sample_vals,col_uid) values ('code','INTEGER','fa52cd88-6053-4f1e-9694-e15339aaf79a','None','1000101,1000301,1000401','747e6a1f-808d-4aa2-95ab-577c5699e6ea'),('description','VARCHAR(255)','fa52cd88-6053-4f1e-9694-e15339aaf79a','None','Afognak Lake, AK: Afognak Lake Airport,Granite Mountain, AK: Bear Creek Mining Strip,Lik, AK: Lik Mining Camp','4a4147cb-9739-4adc-a6e3-f6c84df0dddc')
# 2024-08-18 19:10:53,624 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,625 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_cancellation`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_cancellation`
# 2024-08-18 19:10:53,626 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,626 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,626 INFO sqlalchemy.engine.Engine select * from `l_cancellation` LIMIT 3
# INFO:sqlalchemy.engine.Engine:select * from `l_cancellation` LIMIT 3
# 2024-08-18 19:10:53,626 INFO sqlalchemy.engine.Engine [generated in 0.00101s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00101s] {}
# [{'Code': 'A', 'Description': 'Carrier'}, {'Code': 'B', 'Description': 'Weather'}, {'Code': 'C', 'Description': 'National Air System'}]
# [{'Code': 'A', 'Description': 'Carrier'}, {'Code': 'B', 'Description': 'Weather'}, {'Code': 'C', 'Description': 'National Air System'}]
# INFO:root:executing insert into cols (col_name,col_type,col_table_uid,col_comment,col_sample_vals,col_uid) values ('code','CHAR(1)','8d9cb248-9ced-402f-b06b-0a4c3d9c5b4c','None','A,B,C','a094503f-12a5-4858-b124-b7b8ae5c7963'),('description','VARCHAR(255)','8d9cb248-9ced-402f-b06b-0a4c3d9c5b4c','None','Carrier,Weather,National Air System','abcd3000-9f07-4246-88f7-c82f9a132f20')
# 2024-08-18 19:10:53,626 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-18 19:10:53,626 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `l_city_market_id`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `l_city_market_id`
# 2024-08-18 19:10:53,641 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-18 19:10:53,644 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-18 19:10:53,644 INFO sqlalchemy.engine.Engine select * from `l_city_market_id` LIMIT 3
# INFO:sqlalchemy.engine.Engine:select * from `l_city_market_id` LIMIT 3
# 2024-08-18 19:10:53,644 INFO sqlalchemy.engine.Engine [generated in 0.00082s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00082s] {}
# [{'Code': 30001, 'Description': 'Afognak Lake, AK'}, {'Code': 30003, 'Description': 'Granite Mountain, AK'}, {'Code': 30004, 'Description': 'Lik, AK'}]
# [{'Code': 30001, 'Description': 'Afognak Lake, AK'}, {'Code': 30003, 'Description': 'Granite Mountain, AK'}, {'Code': 30004, 'Description': 'Lik, AK'}]
# ...
# INFO:root:find objs in cols by col_name='divreacheddest' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='divreacheddest' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='divreacheddest',col_units='N/A',col_desc='Distance to the diverted destination in miles.',col_alias='Distance_to_Diverted_Destination',col_desc_justification='Indicates how far the flight was diverted.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='2d1d828e-17c6-4fd1-9be8-a06b9a5e065f'
# INFO:root:find objs in cols by col_name='divactualelapsedtime' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='divactualelapsedtime' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='divactualelapsedtime',col_units='N/A',col_desc='Actual elapsed time for the diverted flight in minutes.',col_alias='Actual_Elapsed_Time_for_Diverted_Flight',col_desc_justification='Indicates the duration of the flight after diversion.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='1cd4d1a0-93c3-45e0-a5de-970658a35cd5'
# INFO:root:find objs in cols by col_name='divarrdelay' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='divarrdelay' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='divarrdelay',col_units='N/A',col_desc='Delay in arrival time for the diverted flight in minutes.',col_alias='Arrival_Delay_for_Diverted_Flight',col_desc_justification='Indicates how late the diverted flight arrived.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='b1279b5e-7fe2-44b4-b642-cde7f3bae556'
# INFO:root:find objs in cols by col_name='divdistance' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='divdistance' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='divdistance',col_units='N/A',col_desc='Distance traveled during the diverted flight in miles.',col_alias='Distance_for_Diverted_Flight',col_desc_justification='Indicates the distance covered by the flight after diversion.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='4ef9db6d-53dd-4d4e-8d53-3c4ca1950edf'
# INFO:root:find objs in cols by col_name='div1airport' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div1airport' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div1airport',col_units='N/A',col_desc='Three-letter code representing the first diverted airport.',col_alias='First_Diverted_Airport_Code',col_desc_justification='Indicates the first airport to which the flight was diverted.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='8f5e8c4d-7381-41c4-988a-8a493690af3e'
# INFO:root:find objs in cols by col_name='div1airportid' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div1airportid' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div1airportid',col_units='N/A',col_desc='Identifier for the first diverted airport.',col_alias='First_Diverted_Airport_ID',col_desc_justification='Indicates the ID of the first airport to which the flight was diverted.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='4353f9c9-f86d-424f-b222-a953a3ef3dc9'
# INFO:root:find objs in cols by col_name='div1airportseqid' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div1airportseqid' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div1airportseqid',col_units='N/A',col_desc='Sequential identifier for the first diverted airport.',col_alias='First_Diverted_Airport_Sequence_ID',col_desc_justification='Indicates the sequential ID for the first diverted airport.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='214890cf-10d4-410c-b1f4-ab18e4f65ae7'
# INFO:root:find objs in cols by col_name='div1wheelson' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div1wheelson' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div1wheelson',col_units='N/A',col_desc='Time when the aircraft''s wheels touch the ground at the first diverted airport.',col_alias='First_Diverted_Wheels_On_Time',col_desc_justification='Indicates the moment of landing at the first diverted airport.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='8f67865e-9572-4ef7-be43-5984a9b277a7'
# INFO:root:find objs in cols by col_name='div1totalgtime' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div1totalgtime' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div1totalgtime',col_units='N/A',col_desc='Total time spent at the first diverted airport in minutes.',col_alias='Total_Time_at_First_Diverted_Airport',col_desc_justification='Indicates how long the flight stayed at the first diverted airport.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='768ef767-db6b-45bb-9de9-eba1ae3b706d'
# INFO:root:find objs in cols by col_name='div1longestgtime' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div1longestgtime' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div1longestgtime',col_units='N/A',col_desc='Longest time spent at the first diverted airport in minutes.',col_alias='Longest_Time_at_First_Diverted_Airport',col_desc_justification='Indicates the maximum time spent at the first diverted airport.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='32eb2f47-51b4-4a43-b1ed-c3ce97c5bd97'
# INFO:root:find objs in cols by col_name='div1wheelsoff' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div1wheelsoff' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div1wheelsoff',col_units='N/A',col_desc='Time when the aircraft''s wheels leave the ground at the first diverted airport.',col_alias='First_Diverted_Wheels_Off_Time',col_desc_justification='Indicates the moment of takeoff from the first diverted airport.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='5ef1e7d1-73d0-45b4-bf97-686e75c092a7'
# INFO:root:find objs in cols by col_name='div1tailnum' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div1tailnum' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div1tailnum',col_units='N/A',col_desc='Tail number of the aircraft at the first diverted airport.',col_alias='First_Diverted_Aircraft_Tail_Number',col_desc_justification='Indicates the specific aircraft used during the diversion.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='0dd3238c-b8e9-4988-97ed-12ccb8c4fed7'
# INFO:root:find objs in cols by col_name='div2airport' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div2airport' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div2airport',col_units='N/A',col_desc='Three-letter code representing the second diverted airport.',col_alias='Second_Diverted_Airport_Code',col_desc_justification='Indicates the second airport to which the flight was diverted.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='8ba771de-e486-47f1-b3e2-0a4c02a27c22'
# INFO:root:find objs in cols by col_name='div2airportid' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div2airportid' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div2airportid',col_units='N/A',col_desc='Identifier for the second diverted airport.',col_alias='Second_Diverted_Airport_ID',col_desc_justification='Indicates the ID of the second airport to which the flight was diverted.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='5358bc7b-b235-4a55-b359-e7bbb0f12b87'
# INFO:root:find objs in cols by col_name='div2airportseqid' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div2airportseqid' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div2airportseqid',col_units='N/A',col_desc='Sequential identifier for the second diverted airport.',col_alias='Second_Diverted_Airport_Sequence_ID',col_desc_justification='Indicates the sequential ID for the second diverted airport.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='df77bd88-4099-49cf-a9eb-cdd8f859e3d5'
# INFO:root:find objs in cols by col_name='div2wheelson' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div2wheelson' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div2wheelson',col_units='N/A',col_desc='Time when the aircraft''s wheels touch the ground at the second diverted airport.',col_alias='Second_Diverted_Wheels_On_Time',col_desc_justification='Indicates the moment of landing at the second diverted airport.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='f765bfe9-78f0-493d-b7d1-7dfe3aa8c81f'
# INFO:root:find objs in cols by col_name='div2totalgtime' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div2totalgtime' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div2totalgtime',col_units='N/A',col_desc='Total time spent at the second diverted airport in minutes.',col_alias='Total_Time_at_Second_Diverted_Airport',col_desc_justification='Indicates how long the flight stayed at the second diverted airport.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='3480328a-b280-4355-8b07-abfd0157cc32'
# INFO:root:find objs in cols by col_name='div2longestgtime' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div2longestgtime' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:1
# INFO:root:executing update cols SET col_name='div2longestgtime',col_units='N/A',col_desc='Longest time spent at the second diverted airport in minutes.',col_alias='Longest_Time_at_Second_Diverted_Airport',col_desc_justification='Indicates the maximum time spent at the second diverted airport.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='e6f2bd66-25ef-4b0f-8afe-775610dcd4f5'
# INFO:root:find objs in cols by col_name='div2wheelsoff' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2'
# INFO:root:fetch select * from cols where col_name='div2wheelsoff' and col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' with nrows:0
# INFO:root:executing update cols SET col_name='div2wheelsoff',col_units='N/A',col_desc='Time when the aircraft''s wheels leave the ground at the second diverted airport.',col_alias='Second_Diverted_Wheels_Off_Time',col_desc_justification='Indicates the moment of takeoff from the second diverted airport.',col_table_uid='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='None'
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 run_all(["travel","pharma","auto","grants"])
#
# Cell In[34], line 8, in run_all(ucs, steps)
#       6 for k in ucs:
#       7     ta=TAGenie()
# ----> 8     ta.process(use_cases[k],steps=steps)
#
# File e:\code\taskAnalytics\taGenie.py:32, in TAGenie.process(self, use_case, steps)
#      30 else:
#      31     user_uid=MngDB().store.find_obj_id("users","user_uid",f"user_name='{use_case['user']['user_name']}'")
# ---> 32 for s in steps:self.Phases[s](user_uid)
#      33 logging.info(f"\n*********************************** done ****************************************************************************\n")
#
# File e:\code\taskAnalytics\taGenie.py:49, in TAGenie.prepare_schema(self, user_uid)
#      47 org_uid=MngDB().get_obj("user",user_uid)["user_org_uid"]
#      48 logging.info(f"\n============================ fetching and annotating DB scheme=======================================================\n")
# ---> 49 return SchemeAnnotator().prepare_schema(org_uid)
#
# File e:\code\taskAnalytics\schemeAnnotator.py:55, in SchemeAnnotator.prepare_schema(self, org_uid)
#      53 def prepare_schema(self,org_uid):
#      54     self.fetch_schema(org_uid)
# ---> 55     self.enrich_schema(org_uid)
#      56     self.summarize_scheme(org_uid)
#
# File e:\code\taskAnalytics\schemeAnnotator.py:101, in SchemeAnnotator.enrich_schema(self, org_uid)
#      96 user_msg=f"try to guess useful information about the semantics of tables and columns based on\
#      97     the following basic list fo tables and columns and their types:{scheme_prompt}.\
#      98         Generate descriptions and longer meaningful English alias names for the original table and column names.\
#      99             Separate descriptive annotation and reasoning on why your guesses are reasonable"
#     100 data_scheme=self.llm.struct_query(sys_msg,user_msg,DataScheme)
# --> 101 for table in data_scheme.tables: self.update_scheme(table,org_uid)
#
# File e:\code\taskAnalytics\schemeAnnotator.py:110, in SchemeAnnotator.update_scheme(self, table, org_uid)
#     107 for col in table.table_columns:
#     108     col_info={"col_name":col.original_column_name.lower(),"col_units":col.column_units,"col_desc":sql_text(col.column_description),
#     109               "col_alias":alias_col_wrap(col.column_alias),"col_desc_justification":sql_text(col.column_annotation_justification),"col_table_uid":table_info['table_uid']}
# --> 110     col_info=self.mngDB.find_update_obj("col",f"col_name='{col.original_column_name.lower()}' and col_table_uid='{table_info['table_uid']}'",col_info)
#
# File e:\code\taskAnalytics\mngDB.py:31, in MngDB.find_update_obj(self, obj_type, criteria, values)
#      29 def find_update_obj(self, obj_type,criteria, values):
#      30     values[obj_type+"_uid"]=self.store.find_obj_id(obj_type+"s",obj_type+"_uid",criteria)
# ---> 31     return self.store.update_obj(obj_type+"s",obj_type+"_uid",values)
#
# File e:\code\taskAnalytics\psgStore.py:101, in PostGreStore.update_obj(self, table_name, pkey_name, values)
#      99 def update_obj(self, table_name,pkey_name,values):
#     100     vals=",".join([f"{k}='{v}'" for k,v in values.items() if k!=pkey_name])
# --> 101     self.execute(f"update {table_name} SET {vals} where {pkey_name}='{values[pkey_name]}'")
#     102     return values
#
# File e:\code\taskAnalytics\psgStore.py:35, in PostGreStore.execute(self, stmt)
#      33 def execute(self, stmt):
#      34     logging.info(f"executing {stmt}")
# ---> 35     self.conn.cursor().execute(stmt)
#      36     return self
#
# InvalidTextRepresentation: invalid input syntax for type uuid: "None"
# LINE 1: ...='4d6d3460-fa17-43e5-a141-f7c031bc3bf2' where col_uid='None'
#                                                                  ^
