# %%
import logging,sys

# %reload_ext autoreload
# %autoreload 2

# %%
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# %%
use_cases={
        
    "insurance":{
        "user":{
                "user_name":"Michael",
                "user_role":"Actuarial analyst"},
        "org": {
                "org_name":"AcmeInsurance",
                "org_descr":"Large car insurance company",
                "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/accidents",
                "org_data_app":"Government road accident tracking system",
                "data_fmt":"MySQL database"}},
    
    "bank":{
        "user":{
                "user_name":"Peter",
                "user_role":"Credit product manager"},
        "org": {
            "org_name":"AcmeBank",
            "org_descr":"Large retailer bank",
            "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/credit",
            "org_data_app":"Loan tracking system",
            "data_fmt":"MySQL database"}},
    
    "education":{
        "user":{
                "user_name":"Alex",
                "user_role":"Educational polices analyst"},
        "org": {
            "org_name":"California CDE",
            "org_descr":"Government education department",
            "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/cdeschool",
            "org_data_app":"schools management system",
            "data_fmt":"MySQL database"}},
    
    "travel":{
        "user":{
                "user_name":"Bob",
                "user_role":"Travel agent"},
        "org": {
            "org_name":"AcmeBizTravel",
            "org_descr":"Corporate travel agency",
            "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/airlines",
            "org_data_app":"DoT historical data on airlines",
            "data_fmt":"MySQL database"}}
}

education_user_uid='826f238c-8ccf-4d0f-9fa1-00fc88f3717a'
bank_user_uid='f3ec0d93-af1f-4b63-8139-ecb3f787fc10'
insurance_user_uid='4db58872-af93-4b4f-a36a-1d6252806d03'
travel_user_uid='6811be90-6348-44ae-b28e-6f25a9c686a7'
user_uid=travel_user_uid

# %%
from taGenie import TAGenie
for k,v in use_cases.items(): 
    ta=TAGenie()
    ta.generate_use_case(v)
# Out:
# INFO:root:
# ============================ starting provisioning of user and his org=======================================================
#
# INFO:root:connecting to taskanalytics
# INFO:root:find objs in orgs by org_name='AcmeInsurance'
# INFO:root:fetch select * from orgs where org_name='AcmeInsurance' with nrows:1
# INFO:root:executing update orgs SET org_name='AcmeInsurance',org_descr='Large car insurance company',org_conn_str='mysql+pymysql://taskanalytics:leningrad@localhost/accidents',org_data_app='Government road accident tracking system',data_fmt='MySQL database' where org_uid='773946ab-5acc-4af9-abbe-f80468f9f7f4'
# INFO:root:find objs in users by user_name='Michael'
# INFO:root:fetch select * from users where user_name='Michael' with nrows:1
# INFO:root:executing update users SET user_name='Michael',user_role='Actuarial analyst',user_org_uid='773946ab-5acc-4af9-abbe-f80468f9f7f4' where user_uid='ddfe120b-e3e7-41cf-b7a6-0dd53a942828'
# INFO:root:
# ============================ fetching and annotating DB scheme=======================================================
#
# INFO:root:connecting to taskanalytics
# INFO:root:fetch select * from tables where table_org_uid='773946ab-5acc-4af9-abbe-f80468f9f7f4' with nrows:0
# INFO:root:find obj in orgs by 773946ab-5acc-4af9-abbe-f80468f9f7f4
# INFO:root:find objs in orgs by org_uid='773946ab-5acc-4af9-abbe-f80468f9f7f4'
# INFO:root:fetch select * from orgs where org_uid='773946ab-5acc-4af9-abbe-f80468f9f7f4' with nrows:1
# 2024-08-17 17:23:21,732 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# INFO:sqlalchemy.engine.Engine:SELECT DATABASE()
# 2024-08-17 17:23:21,732 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,748 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# INFO:sqlalchemy.engine.Engine:SELECT @@sql_mode
# 2024-08-17 17:23:21,748 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,748 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# INFO:sqlalchemy.engine.Engine:SELECT @@lower_case_table_names
# 2024-08-17 17:23:21,752 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,768 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:21,769 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `accidents`
# INFO:sqlalchemy.engine.Engine:SHOW FULL TABLES FROM `accidents`
# 2024-08-17 17:23:21,769 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,801 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-17 17:23:21,801 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:21,801 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `nesreca`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `nesreca`
# 2024-08-17 17:23:21,801 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,837 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-17 17:23:21,837 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:21,837 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `nesreca`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `nesreca`
# 2024-08-17 17:23:21,837 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,837 INFO sqlalchemy.engine.Engine
#                     select table_schema, table_name, column_name
#                     from information_schema.columns
#                     where (table_schema, table_name, lower(column_name)) in
#                     ((%(table_data_1_1)s, %(table_data_1_2)s, %(table_data_1_3)s));
#
# INFO:sqlalchemy.engine.Engine:
#                     select table_schema, table_name, column_name
#                     from information_schema.columns
#                     where (table_schema, table_name, lower(column_name)) in
#                     ((%(table_data_1_1)s, %(table_data_1_2)s, %(table_data_1_3)s));
#
# 2024-08-17 17:23:21,837 INFO sqlalchemy.engine.Engine [generated in 0.00098s] {'table_data_1_1': 'accidents', 'table_data_1_2': 'upravna_enota', 'table_data_1_3': 'id_upravna_enota'}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00098s] {'table_data_1_1': 'accidents', 'table_data_1_2': 'upravna_enota', 'table_data_1_3': 'id_upravna_enota'}
# 2024-08-17 17:23:21,837 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-17 17:23:21,851 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:21,852 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `oseba`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `oseba`
# 2024-08-17 17:23:21,852 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,856 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-17 17:23:21,857 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:21,859 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `oseba`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `oseba`
# 2024-08-17 17:23:21,860 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,862 INFO sqlalchemy.engine.Engine
#                     select table_schema, table_name, column_name
#                     from information_schema.columns
#                     where (table_schema, table_name, lower(column_name)) in
#                     ((%(table_data_1_1)s, %(table_data_1_2)s, %(table_data_1_3)s), (%(table_data_2_1)s, %(table_data_2_2)s, %(table_data_2_3)s));
#
# INFO:sqlalchemy.engine.Engine:
#                     select table_schema, table_name, column_name
#                     from information_schema.columns
#                     where (table_schema, table_name, lower(column_name)) in
#                     ((%(table_data_1_1)s, %(table_data_1_2)s, %(table_data_1_3)s), (%(table_data_2_1)s, %(table_data_2_2)s, %(table_data_2_3)s));
#
# 2024-08-17 17:23:21,863 INFO sqlalchemy.engine.Engine [cached since 0.0201s ago] {'table_data_1_1': 'accidents', 'table_data_1_2': 'nesreca', 'table_data_1_3': 'id_nesreca', 'table_data_2_1': 'accidents', 'table_data_2_2': 'upravna_enota', 'table_data_2_3': 'id_upravna_enota'}
# INFO:sqlalchemy.engine.Engine:[cached since 0.0201s ago] {'table_data_1_1': 'accidents', 'table_data_1_2': 'nesreca', 'table_data_1_3': 'id_nesreca', 'table_data_2_1': 'accidents', 'table_data_2_2': 'upravna_enota', 'table_data_2_3': 'id_upravna_enota'}
# 2024-08-17 17:23:21,906 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-17 17:23:21,907 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:21,908 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `upravna_enota`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `upravna_enota`
# 2024-08-17 17:23:21,909 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,912 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-17 17:23:21,914 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:21,915 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `upravna_enota`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `upravna_enota`
# 2024-08-17 17:23:21,915 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,915 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# INFO:root:executing insert into tables (table_name,table_org_uid,table_pkeys,table_fkeys,table_uid) values ('nesreca','773946ab-5acc-4af9-abbe-f80468f9f7f4','{"constrained_columns": ["id_nesreca"], "name": null}','[{"name": "nesreca_ibfk_1", "constrained_columns": ["upravna_enota"], "referred_schema": null, "referred_table": "upravna_enota", "referred_columns": ["id_upravna_enota"], "options": {"onupdate": "CASCADE", "ondelete": "CASCADE"}}]','c31ef375-2508-4007-820f-f17aa6b42261'),('oseba','773946ab-5acc-4af9-abbe-f80468f9f7f4','{"name": null, "constrained_columns": []}','[{"name": "oseba_ibfk_1", "constrained_columns": ["id_nesreca"], "referred_schema": null, "referred_table": "nesreca", "referred_columns": ["id_nesreca"], "options": {"onupdate": "CASCADE", "ondelete": "CASCADE"}}, {"name": "oseba_ibfk_2", "constrained_columns": ["upravna_enota"], "referred_schema": null, "referred_table": "upravna_enota", "referred_columns": ["id_upravna_enota"], "options": {"onupdate": "CASCADE", "ondelete": "CASCADE"}}]','5defbd34-2c8a-4700-b610-859c8684f133'),('upravna_enota','773946ab-5acc-4af9-abbe-f80468f9f7f4','{"constrained_columns": ["id_upravna_enota"], "name": null}','[]','ae23c100-fe93-416f-88fe-951b6bad4f27')
# 2024-08-17 17:23:21,915 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:21,915 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `nesreca`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `nesreca`
# 2024-08-17 17:23:21,915 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,933 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-17 17:23:21,934 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:21,935 INFO sqlalchemy.engine.Engine select * from nesreca LIMIT 3
# INFO:sqlalchemy.engine.Engine:select * from nesreca LIMIT 3
# 2024-08-17 17:23:21,936 INFO sqlalchemy.engine.Engine [generated in 0.00232s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00232s] {}
# INFO:root:executing insert into cols (col_name,col_type,col_table_uid,col_comment,col_sample_vals,col_uid) values ('id_nesreca','CHAR(6)','c31ef375-2508-4007-820f-f17aa6b42261','None','036738,036744,036755','7db68455-3215-44dd-97d6-dcab4d21c017'),('klas_nesreca','CHAR(1)','c31ef375-2508-4007-820f-f17aa6b42261','None','H,B,L','e873e84c-c825-4d66-b425-92824788ba73'),('upravna_enota','CHAR(4)','c31ef375-2508-4007-820f-f17aa6b42261','None','5564,5511,5564','b73e976d-7171-474c-a0f4-2c6a4049b41d'),('cas_nesreca','DATETIME','c31ef375-2508-4007-820f-f17aa6b42261','None','1995-01-01 15:30:00,1995-01-02 12:45:00,1995-01-01 06:00:00','3fe0fdbf-d78d-4029-a36e-fa820268d089'),('naselje_ali_izven','CHAR(1)','c31ef375-2508-4007-820f-f17aa6b42261','None','D,N,N','9f9d9564-a493-4d7c-b3eb-1402b7f2e59c'),('kategorija_cesta','CHAR(1)','c31ef375-2508-4007-820f-f17aa6b42261','None','V,L,M','5093bb57-ffe2-4e94-a8ce-9a0e77338ea3'),('oznaka_cesta_ali_naselje','CHAR(5)','c31ef375-2508-4007-820f-f17aa6b42261','None','64043,93117,00003','111a29ee-c133-4ad3-916a-9d10be781251'),('tekst_cesta_ali_naselje','VARCHAR(25)','c31ef375-2508-4007-820f-f17aa6b42261','None','PERNICA,IDRIJA-KOČEVŠE-KODER-VOJS,MEJA A-VIČ-ORMOŽ-MEJA RH','67dc26f7-2112-4b06-a482-57aea777fc01'),('oznaka_odsek_ali_ulica','CHAR(5)','c31ef375-2508-4007-820f-f17aa6b42261','None','00000,00000,00246','3cb6b3c2-4765-4b4e-b5a8-57fcc3d424bc'),('tekst_odsek_ali_ulica','VARCHAR(25)','c31ef375-2508-4007-820f-f17aa6b42261','None','NI ULIC,NI ODSEKOV,MARIBOR(TEZNO)-HAJDINA','11696860-e625-4a92-90b9-dfee8703f159'),('stacionazna_ali_hisna_st','VARCHAR(9)','c31ef375-2508-4007-820f-f17aa6b42261','None','None,None,None','ff17feab-468e-42b8-9b3d-4d0166adb940'),('opis_prizorisce','CHAR(1)','c31ef375-2508-4007-820f-f17aa6b42261','None','C,C,C','31038197-4c24-4837-906f-a0bdc9c820f4'),('vzrok_nesreca','CHAR(2)','c31ef375-2508-4007-820f-f17aa6b42261','None','PR,HI,SV','c1fe9123-1b2f-43d8-82d8-55840fed0079'),('tip_nesreca','CHAR(2)','c31ef375-2508-4007-820f-f17aa6b42261','None','BT,BT,ÈT','0c7901d3-1f51-4ce7-af3d-6baca87c8dd3'),('vreme_nesreca','CHAR(1)','c31ef375-2508-4007-820f-f17aa6b42261','None','O,J,O','a1ada868-ace9-4bac-95fa-f004cb538266'),('stanje_promet','CHAR(1)','c31ef375-2508-4007-820f-f17aa6b42261','None','R,N,R','f734d980-f02b-48a1-97fb-0a92b0f25e51'),('stanje_vozisce','CHAR(2)','c31ef375-2508-4007-820f-f17aa6b42261','None','MO,MO,MO','72560f32-7ea6-4fc9-adbe-de231305e726'),('stanje_povrsina_vozisce','CHAR(2)','c31ef375-2508-4007-820f-f17aa6b42261','None','A,A,A','b548ce3e-ebeb-4075-aea7-6fab3297bd4c'),('x','INTEGER','c31ef375-2508-4007-820f-f17aa6b42261','None','556102,423380,555372','cd781e44-56e4-4340-af9a-52404575b57d'),('y','INTEGER','c31ef375-2508-4007-820f-f17aa6b42261','None','159758,95390,150260','cc53726e-1802-4243-b0f4-592f45ed42d9'),('x_wgs84','DOUBLE','c31ef375-2508-4007-820f-f17aa6b42261','None','15.7271485845696,14.0060339182733,15.716499936082','8939558e-5f84-45e6-be45-6f04ab3d49a3'),('y_wgs84','DOUBLE','c31ef375-2508-4007-820f-f17aa6b42261','None','46.5795099965885,45.998372031671,46.4941258818011','2edcba16-9ca4-4e32-a6a1-809a7eaa5711')
# 2024-08-17 17:23:21,998 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:21,999 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `oseba`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `oseba`
# 2024-08-17 17:23:21,999 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:21,999 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-17 17:23:21,999 INFO sqlalchemy.engine.Engine select * from oseba LIMIT 3
# INFO:sqlalchemy.engine.Engine:select * from oseba LIMIT 3
# 2024-08-17 17:23:21,999 INFO sqlalchemy.engine.Engine [generated in 0.00080s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00080s] {}
# INFO:root:executing insert into cols (col_name,col_type,col_table_uid,col_comment,col_sample_vals,col_uid) values ('id_nesreca','CHAR(6)','5defbd34-2c8a-4700-b610-859c8684f133','None','036738,036738,036738','9f62908b-a001-41eb-baae-dde393b71dc5'),('povzrocitelj_ali_udelezenec','CHAR(1)','5defbd34-2c8a-4700-b610-859c8684f133','None','D,D,N','0cff6900-cb94-43b3-8859-3dc2920aa0b3'),('starost','TINYINT','5defbd34-2c8a-4700-b610-859c8684f133','None','38,28,12','3241f372-915f-4b39-96c8-be470f0652fb'),('spol','CHAR(1)','5defbd34-2c8a-4700-b610-859c8684f133','None','1,1,2','a65ca97b-27ef-4d2a-b962-7a05ddbbf5b9'),('upravna_enota','CHAR(4)','5defbd34-2c8a-4700-b610-859c8684f133','None','5507,5599,5507','4f0b3b9e-d815-4df1-ae9c-7f9f847ab06c'),('drzavljanstvo','CHAR(3)','5defbd34-2c8a-4700-b610-859c8684f133','None','005,211,005','27bb19f0-7633-49db-9aba-32f20bcc333f'),('poskodba','CHAR(1)','5defbd34-2c8a-4700-b610-859c8684f133','None','L,P,H','de25e2bc-7bca-4668-8ade-28e498a4faa2'),('vrsta_udelezenca','CHAR(2)','5defbd34-2c8a-4700-b610-859c8684f133','None','TV,OA,PT','b6425b5e-cad4-49bd-a5e2-93391582d6cb'),('varnostni_pas_ali_celada','CHAR(1)','5defbd34-2c8a-4700-b610-859c8684f133','None','N,N,0','ec5ba702-9828-4ccf-8fb1-8df9d7a73a26'),('vozniski_staz_ll','TINYINT','5defbd34-2c8a-4700-b610-859c8684f133','None','6,10,0','b4bbba16-1cff-4541-a54d-4facc6e72ff9'),('vozniski_staz_mm','TINYINT','5defbd34-2c8a-4700-b610-859c8684f133','None','None,None,None','0afb052e-79e1-4c76-8421-d37d977e3752'),('alkotest','DECIMAL(3, 2)','5defbd34-2c8a-4700-b610-859c8684f133','None','0.11,0.00,None','7b15ee18-c5c9-43fe-9b05-541c0221965d'),('strokovni_pregled','DECIMAL(3, 2)','5defbd34-2c8a-4700-b610-859c8684f133','None','0.08,0.00,None','044d22a4-95fa-4212-b6ba-da361f53ec82'),('starost_d','CHAR(1)','5defbd34-2c8a-4700-b610-859c8684f133','None','D,C,B','75b32b43-657c-412b-957a-8639add63ef0'),('vozniski_staz_d','CHAR(1)','5defbd34-2c8a-4700-b610-859c8684f133','None','B,B,A','041a4888-fc78-4118-83c1-470e564545fe'),('alkotest_d','CHAR(1)','5defbd34-2c8a-4700-b610-859c8684f133','None','B,A,N','7349ae47-a173-4e6d-86dc-3eda8962a080'),('strokovni_pregled_d','CHAR(1)','5defbd34-2c8a-4700-b610-859c8684f133','None','B,A,N','118dac47-38c7-4926-be78-ef87d0ae754f')
# 2024-08-17 17:23:22,019 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-17 17:23:22,019 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `upravna_enota`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `upravna_enota`
# 2024-08-17 17:23:22,019 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-17 17:23:22,019 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# 2024-08-17 17:23:22,032 INFO sqlalchemy.engine.Engine select * from upravna_enota LIMIT 3
# INFO:sqlalchemy.engine.Engine:select * from upravna_enota LIMIT 3
# 2024-08-17 17:23:22,033 INFO sqlalchemy.engine.Engine [generated in 0.00110s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00110s] {}
# INFO:root:executing insert into cols (col_name,col_type,col_table_uid,col_comment,col_sample_vals,col_uid) values ('id_upravna_enota','CHAR(4)','ae23c100-fe93-416f-88fe-951b6bad4f27','None','5501,5502,5503','99c5ee25-dedd-4585-b528-9c1747ec65df'),('ime_upravna_enota','VARCHAR(255)','ae23c100-fe93-416f-88fe-951b6bad4f27','None','Ajdovščina,Brežice,Celje','e965db98-2d77-4376-b213-fa3c33d0d27a'),('st_prebivalcev','INTEGER','ae23c100-fe93-416f-88fe-951b6bad4f27','None','23507,23253,62049','f0e898c0-72ee-4eef-a4a9-8e8495d1ea10'),('povrsina','SMALLINT','ae23c100-fe93-416f-88fe-951b6bad4f27','None','353,268,230','e0a69b3a-9b26-4d52-9e09-762c735cd8a8')
# INFO:root:find obj in orgs by 773946ab-5acc-4af9-abbe-f80468f9f7f4
# INFO:root:find objs in orgs by org_uid='773946ab-5acc-4af9-abbe-f80468f9f7f4'
# INFO:root:fetch select * from orgs where org_uid='773946ab-5acc-4af9-abbe-f80468f9f7f4' with nrows:1
# INFO:root:connecting to taskanalytics
# INFO:root:fetch select * from tables where table_org_uid='773946ab-5acc-4af9-abbe-f80468f9f7f4' with nrows:3
# INFO:root:fetch select * from cols where col_table_uid='c31ef375-2508-4007-820f-f17aa6b42261' with nrows:22
# INFO:root:fetch select * from cols where col_table_uid='5defbd34-2c8a-4700-b610-859c8684f133' with nrows:17
# INFO:root:fetch select * from cols where col_table_uid='ae23c100-fe93-416f-88fe-951b6bad4f27' with nrows:4

# %%
#from visGen import VisGen
#vg=VisGen()
# vg.generate_user_visuals(education_user_uid)
# Out:
# INFO:root:connecting to taskanalytics
# INFO:root:fetch select kpis.kpi_uid from kpis join tasks on kpis.kpi_task_uid=tasks.task_uid where tasks.task_user_uid='826f238c-8ccf-4d0f-9fa1-00fc88f3717a' with nrows:46
# INFO:root:find obj in kpis by 8fa3df69-475f-42d5-906c-3e0fde8f2abb
# INFO:root:find objs in kpis by kpi_uid='8fa3df69-475f-42d5-906c-3e0fde8f2abb'
# INFO:root:fetch select * from kpis where kpi_uid='8fa3df69-475f-42d5-906c-3e0fde8f2abb' with nrows:1
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:llm retunr=DIV_HTML_CODE="<div id='school-visualization' style='width: 500px; height: 300px;'></div>\n<script src='https://d3js.org/d3.v7.min.js'></script>\n<script>\n    const data = [{'Total_Number_of_Schools': 17686}];\n    const totalSchools = data[0].Total_Number_of_Schools;\n\n    const width = 500;\n    const height = 300;\n    const margin = {top: 20, right: 30, bottom: 40, left: 40};\n\n    const svg = d3.select('#school-visualization')\n        .append('svg')\n        .attr('width', width)\n        .attr('height', height);\n\n    const x = d3.scaleBand()\n        .domain(['Total Schools'])\n        .range([margin.left, width - margin.right])\n        .padding(0.1);\n\n    const y = d3.scaleLinear()\n        .domain([0, totalSchools]).nice()\n        .range([height - margin.bottom, margin.top]);\n\n    svg.append('g')\n        .attr('fill', 'steelblue')\n        .selectAll('rect')\n        .data([totalSchools])\n        .enter()\n        .append('rect')\n        .attr('x', x('Total Schools'))\n        .attr('y', y)\n        .attr('height', d => y(0) - y(d))\n        .attr('width', x.bandwidth());\n\n    svg.append('g')\n        .attr('transform', `translate(0,${height - margin.bottom})`)\n        .call(d3.axisBottom(x));\n\n    svg.append('g')\n        .attr('transform', `translate(${margin.left},0)`)\n        .call(d3.axisLeft(y));\n\n    svg.append('text')\n        .attr('x', width / 2)\n        .attr('y', margin.top)\n        .attr('text-anchor', 'middle')\n        .text('Total Number of Schools');\n</script>" visualization_type='Bar Chart'
# INFO:root:executing update kpis SET sql_vis='<div id=''school-visualization'' style=''width: 500px; height: 300px;''></div>
# <script src=''https://d3js.org/d3.v7.min.js''></script>
# <script>
#     const data = [{''Total_Number_of_Schools'': 17686}];
#     const totalSchools = data[0].Total_Number_of_Schools;
#
#     const width = 500;
#     const height = 300;
#     const margin = {top: 20, right: 30, bottom: 40, left: 40};
#
#     const svg = d3.select(''#school-visualization'')
#         .append(''svg'')
#         .attr(''width'', width)
#         .attr(''height'', height);
#
#     const x = d3.scaleBand()
#         .domain([''Total Schools''])
#         .range([margin.left, width - margin.right])
#         .padding(0.1);
#
#     const y = d3.scaleLinear()
#         .domain([0, totalSchools]).nice()
#         .range([height - margin.bottom, margin.top]);
#
#     svg.append(''g'')
#         .attr(''fill'', ''steelblue'')
#         .selectAll(''rect'')
#         .data([totalSchools])
#         .enter()
#         .append(''rect'')
#         .attr(''x'', x(''Total Schools''))
#         .attr(''y'', y)
#         .attr(''height'', d => y(0) - y(d))
#         .attr(''width'', x.bandwidth());
#
#     svg.append(''g'')
#         .attr(''transform'', `translate(0,${height - margin.bottom})`)
#         .call(d3.axisBottom(x));
#
#     svg.append(''g'')
#         .attr(''transform'', `translate(${margin.left},0)`)
#         .call(d3.axisLeft(y));
#
#     svg.append(''text'')
#         .attr(''x'', width / 2)
#         .attr(''y'', margin.top)
#         .attr(''text-anchor'', ''middle'')
#         .text(''Total Number of Schools'');
# </script>' where kpi_uid='8fa3df69-475f-42d5-906c-3e0fde8f2abb'
# INFO:root:find obj in kpis by b1afbd69-d440-486d-a134-08c74c9757b5
# INFO:root:find objs in kpis by kpi_uid='b1afbd69-d440-486d-a134-08c74c9757b5'
# INFO:root:fetch select * from kpis where kpi_uid='b1afbd69-d440-486d-a134-08c74c9757b5' with nrows:1
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:llm retunr=DIV_HTML_CODE="<div id='frpm-participation-chart' style='width: 600px; height: 400px;'></div>\n<script src='https://d3js.org/d3.v7.min.js'></script>\n<script>\n    const data = [{'school name': 'FAME Public Charter', 'avg_frpm_participation_rate': 0.657773689052438}, {'school name': 'Envision Academy for Arts & Technology', 'avg_frpm_participation_rate': 0.470886075949367}, {'school name': 'Aspire California College Preparatory Academy', 'avg_frpm_participation_rate': 0.717213114754098}, {'school name': 'Community School for Creative Education', 'avg_frpm_participation_rate': 0.727748691099476}, {'school name': 'Yu Ming Charter', 'avg_frpm_participation_rate': 0.0817120622568093}, {'school name': 'Urban Montessori Charter', 'avg_frpm_participation_rate': 0.362007168458781}, {'school name': 'Alameda County Juvenile Hall/Court', 'avg_frpm_participation_rate': 0.403314917127072}, {'school name': 'Alameda County Community', 'avg_frpm_participation_rate': 0.805054151624549}, {'school name': 'Cox Academy', 'avg_frpm_participation_rate': 0.932998324958124}, {'school name': 'Lazear Charter Academy', 'avg_frpm_participation_rate': 0.91533180778032}];\n\n    const margin = {top: 20, right: 30, bottom: 40, left: 40},\n          width = 600 - margin.left - margin.right,\n          height = 400 - margin.top - margin.bottom;\n\n    const svg = d3.select('#frpm-participation-chart')\n        .append('svg')\n        .attr('width', width + margin.left + margin.right)\n        .attr('height', height + margin.top + margin.bottom)\n      .append('g')\n        .attr('transform', `translate(${margin.left},${margin.top})`);\n\n    const x = d3.scaleBand()\n        .domain(data.map(d => d['school name']))\n        .range([0, width])\n        .padding(0.1);\n\n    const y = d3.scaleLinear()\n        .domain([0, 1])\n        .nice()\n        .range([height, 0]);\n\n    svg.append('g')\n        .attr('class', 'x-axis')\n        .attr('transform', `translate(0,${height})`)\n        .call(d3.axisBottom(x));\n\n    svg.append('g')\n        .attr('class', 'y-axis')\n        .call(d3.axisLeft(y).ticks(10, '%'));\n\n    svg.selectAll('.bar')\n        .data(data)\n      .enter().append('rect')\n        .attr('class', 'bar')\n        .attr('x', d => x(d['school name']))\n        .attr('y', d => y(d['avg_frpm_participation_rate']))\n        .attr('height', d => height - y(d['avg_frpm_participation_rate']))\n        .attr('width', x.bandwidth())\n        .attr('fill', '#69b3a2');\n\n    svg.append('text')\n        .attr('x', width / 2)\n        .attr('y', 0 - margin.top / 2)\n        .attr('text-anchor', 'middle')\n        .style('font-size', '16px')\n        .text('Average Free and Reduced Price Meal Participation Rate by School');\n\n    svg.append('text')\n        .attr('transform', 'rotate(-90)')\n        .attr('y', 0 - margin.left)\n        .attr('x', 0 - (height / 2))\n        .attr('dy', '1em')\n        .attr('text-anchor', 'middle')\n        .text('Participation Rate');\n\n    svg.append('text')\n        .attr('x', width / 2)\n        .attr('y', height + margin.bottom / 1.5)\n        .attr('text-anchor', 'middle')\n        .text('School Name');\n</script>" visualization_type='Bar Chart'
# INFO:root:executing update kpis SET sql_vis='<div id=''frpm-participation-chart'' style=''width: 600px; height: 400px;''></div>
# <script src=''https://d3js.org/d3.v7.min.js''></script>
# <script>
#     const data = [{''school name'': ''FAME Public Charter'', ''avg_frpm_participation_rate'': 0.657773689052438}, {''school name'': ''Envision Academy for Arts & Technology'', ''avg_frpm_participation_rate'': 0.470886075949367}, {''school name'': ''Aspire California College Preparatory Academy'', ''avg_frpm_participation_rate'': 0.717213114754098}, {''school name'': ''Community School for Creative Education'', ''avg_frpm_participation_rate'': 0.727748691099476}, {''school name'': ''Yu Ming Charter'', ''avg_frpm_participation_rate'': 0.0817120622568093}, {''school name'': ''Urban Montessori Charter'', ''avg_frpm_participation_rate'': 0.362007168458781}, {''school name'': ''Alameda County Juvenile Hall/Court'', ''avg_frpm_participation_rate'': 0.403314917127072}, {''school name'': ''Alameda County Community'', ''avg_frpm_participation_rate'': 0.805054151624549}, {''school name'': ''Cox Academy'', ''avg_frpm_participation_rate'': 0.932998324958124}, {''school name'': ''Lazear Charter Academy'', ''avg_frpm_participation_rate'': 0.91533180778032}];
#
#     const margin = {top: 20, right: 30, bottom: 40, left: 40},
#           width = 600 - margin.left - margin.right,
#           height = 400 - margin.top - margin.bottom;
#
#     const svg = d3.select(''#frpm-participation-chart'')
#         .append(''svg'')
#         .attr(''width'', width + margin.left + margin.right)
#         .attr(''height'', height + margin.top + margin.bottom)
#       .append(''g'')
#         .attr(''transform'', `translate(${margin.left},${margin.top})`);
#
#     const x = d3.scaleBand()
#         .domain(data.map(d => d[''school name'']))
#         .range([0, width])
#         .padding(0.1);
#
#     const y = d3.scaleLinear()
#         .domain([0, 1])
#         .nice()
#         .range([height, 0]);
#
#     svg.append(''g'')
#         .attr(''class'', ''x-axis'')
#         .attr(''transform'', `translate(0,${height})`)
#         .call(d3.axisBottom(x));
#
#     svg.append(''g'')
#         .attr(''class'', ''y-axis'')
#         .call(d3.axisLeft(y).ticks(10, ''%''));
#
#     svg.selectAll(''.bar'')
#         .data(data)
#       .enter().append(''rect'')
#         .attr(''class'', ''bar'')
#         .attr(''x'', d => x(d[''school name'']))
#         .attr(''y'', d => y(d[''avg_frpm_participation_rate'']))
#         .attr(''height'', d => height - y(d[''avg_frpm_participation_rate'']))
#         .attr(''width'', x.bandwidth())
#         .attr(''fill'', ''#69b3a2'');
#
#     svg.append(''text'')
#         .attr(''x'', width / 2)
#         .attr(''y'', 0 - margin.top / 2)
#         .attr(''text-anchor'', ''middle'')
#         .style(''font-size'', ''16px'')
#         .text(''Average Free and Reduced Price Meal Participation Rate by School'');
#
#     svg.append(''text'')
#         .attr(''transform'', ''rotate(-90)'')
#         .attr(''y'', 0 - margin.left)
#         .attr(''x'', 0 - (height / 2))
#         .attr(''dy'', ''1em'')
#         .attr(''text-anchor'', ''middle'')
#         .text(''Participation Rate'');
#
#     svg.append(''text'')
#         .attr(''x'', width / 2)
#         .attr(''y'', height + margin.bottom / 1.5)
#         .attr(''text-anchor'', ''middle'')
#         .text(''School Name'');
# </script>' where kpi_uid='b1afbd69-d440-486d-a134-08c74c9757b5'
# INFO:root:find obj in kpis by 019cf690-5e24-4bef-98d2-b8dd716cee12
# INFO:root:find objs in kpis by kpi_uid='019cf690-5e24-4bef-98d2-b8dd716cee12'
# INFO:root:fetch select * from kpis where kpi_uid='019cf690-5e24-4bef-98d2-b8dd716cee12' with nrows:1
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:llm retunr=DIV_HTML_CODE="<div id='student-demographics' style='width: 800px; height: 600px;'></div>\n<script src='https://d3js.org/d3.v7.min.js'></script>\n<script>\nvar data = [{'school': 'FAME Public Charter', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'school type': 'K-12 Schools (Public)', 'charter school (y/n)': 1, 'total_enrollment_k12': 1087.0, 'total_free_meal_count_k12': 565.0, 'total_frpm_count_k12': 715.0, 'total_enrollment_ages_5_17': 1070.0, 'total_free_meal_count_ages_5_17': 553.0, 'total_frpm_count_ages_5_17': 702.0}, {'school': 'Envision Academy for Arts & Technology', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'school type': 'High Schools (Public)', 'charter school (y/n)': 1, 'total_enrollment_k12': 395.0, 'total_free_meal_count_k12': 186.0, 'total_frpm_count_k12': 186.0, 'total_enrollment_ages_5_17': 376.0, 'total_free_meal_count_ages_5_17': 182.0, 'total_frpm_count_ages_5_17': 182.0}, {'school': 'Aspire California College Preparatory Academy', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'school type': 'High Schools (Public)', 'charter school (y/n)': 1, 'total_enrollment_k12': 244.0, 'total_free_meal_count_k12': 134.0, 'total_frpm_count_k12': 175.0, 'total_enrollment_ages_5_17': 230.0, 'total_free_meal_count_ages_5_17': 128.0, 'total_frpm_count_ages_5_17': 168.0}, {'school': 'Community School for Creative Education', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'school type': 'Elementary Schools (Public)', 'charter school (y/n)': 1, 'total_enrollment_k12': 191.0, 'total_free_meal_count_k12': 113.0, 'total_frpm_count_k12': 139.0, 'total_enrollment_ages_5_17': 190.0, 'total_free_meal_count_ages_5_17': 113.0, 'total_frpm_count_ages_5_17': 139.0}, {'school': 'Yu Ming Charter', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'school type': 'Elementary Schools (Public)', 'charter school (y/n)': 1, 'total_enrollment_k12': 257.0, 'total_free_meal_count_k12': 14.0, 'total_frpm_count_k12': 21.0, 'total_enrollment_ages_5_17': 257.0, 'total_free_meal_count_ages_5_17': 14.0, 'total_frpm_count_ages_5_17': 21.0}, {'school': 'Urban Montessori Charter', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'school type': 'Elementary Schools (Public)', 'charter school (y/n)': 1, 'total_enrollment_k12': 279.0, 'total_free_meal_count_k12': 81.0, 'total_frpm_count_k12': 101.0, 'total_enrollment_ages_5_17': 273.0, 'total_free_meal_count_ages_5_17': 78.0, 'total_frpm_count_ages_5_17': 98.0}, {'school': 'Alameda County Juvenile Hall/Court', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'school type': 'Juvenile Court Schools', 'charter school (y/n)': 0, 'total_enrollment_k12': 181.0, 'total_free_meal_count_k12': 71.0, 'total_frpm_count_k12': 73.0, 'total_enrollment_ages_5_17': 160.0, 'total_free_meal_count_ages_5_17': 66.0, 'total_frpm_count_ages_5_17': 68.0}, {'school': 'Alameda County Community', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'school type': 'County Community', 'charter school (y/n)': 0, 'total_enrollment_k12': 277.0, 'total_free_meal_count_k12': 190.0, 'total_frpm_count_k12': 223.0, 'total_enrollment_ages_5_17': 221.0, 'total_free_meal_count_ages_5_17': 145.0, 'total_frpm_count_ages_5_17': 172.0}, {'school': 'Cox Academy', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'school type': 'Elementary Schools (Public)', 'charter school (y/n)': 1, 'total_enrollment_k12': 597.0, 'total_free_meal_count_k12': 493.0, 'total_frpm_count_k12': 557.0, 'total_enrollment_ages_5_17': 586.0, 'total_free_meal_count_ages_5_17': 483.0, 'total_frpm_count_ages_5_17': 546.0}, {'school': 'Lazear Charter Academy', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'school type': 'Elementary Schools (Public)', 'charter school (y/n)': 1, 'total_enrollment_k12': 437.0, 'total_free_meal_count_k12' ...
# INFO:root:executing update kpis SET sql_vis='<div id=''student-demographics'' style=''width: 800px; height: 600px;''></div>
# <script src=''https://d3js.org/d3.v7.min.js''></script>
# <script>
# var data = [{''school'': ''FAME Public Charter'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''school type'': ''K-12 Schools (Public)'', ''charter school (y/n)'': 1, ''total_enrollment_k12'': 1087.0, ''total_free_meal_count_k12'': 565.0, ''total_frpm_count_k12'': 715.0, ''total_enrollment_ages_5_17'': 1070.0, ''total_free_meal_count_ages_5_17'': 553.0, ''total_frpm_count_ages_5_17'': 702.0}, {''school'': ''Envision Academy for Arts & Technology'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''school type'': ''High Schools (Public)'', ''charter school (y/n)'': 1, ''total_enrollment_k12'': 395.0, ''total_free_meal_count_k12'': 186.0, ''total_frpm_count_k12'': 186.0, ''total_enrollment_ages_5_17'': 376.0, ''total_free_meal_count_ages_5_17'': 182.0, ''total_frpm_count_ages_5_17'': 182.0}, {''school'': ''Aspire California College Preparatory Academy'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''school type'': ''High Schools (Public)'', ''charter school (y/n)'': 1, ''total_enrollment_k12'': 244.0, ''total_free_meal_count_k12'': 134.0, ''total_frpm_count_k12'': 175.0, ''total_enrollment_ages_5_17'': 230.0, ''total_free_meal_count_ages_5_17'': 128.0, ''total_frpm_count_ages_5_17'': 168.0}, {''school'': ''Community School for Creative Education'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''school type'': ''Elementary Schools (Public)'', ''charter school (y/n)'': 1, ''total_enrollment_k12'': 191.0, ''total_free_meal_count_k12'': 113.0, ''total_frpm_count_k12'': 139.0, ''total_enrollment_ages_5_17'': 190.0, ''total_free_meal_count_ages_5_17'': 113.0, ''total_frpm_count_ages_5_17'': 139.0}, {''school'': ''Yu Ming Charter'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''school type'': ''Elementary Schools (Public)'', ''charter school (y/n)'': 1, ''total_enrollment_k12'': 257.0, ''total_free_meal_count_k12'': 14.0, ''total_frpm_count_k12'': 21.0, ''total_enrollment_ages_5_17'': 257.0, ''total_free_meal_count_ages_5_17'': 14.0, ''total_frpm_count_ages_5_17'': 21.0}, {''school'': ''Urban Montessori Charter'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''school type'': ''Elementary Schools (Public)'', ''charter school (y/n)'': 1, ''total_enrollment_k12'': 279.0, ''total_free_meal_count_k12'': 81.0, ''total_frpm_count_k12'': 101.0, ''total_enrollment_ages_5_17'': 273.0, ''total_free_meal_count_ages_5_17'': 78.0, ''total_frpm_count_ages_5_17'': 98.0}, {''school'': ''Alameda County Juvenile Hall/Court'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''school type'': ''Juvenile Court Schools'', ''charter school (y/n)'': 0, ''total_enrollment_k12'': 181.0, ''total_free_meal_count_k12'': 71.0, ''total_frpm_count_k12'': 73.0, ''total_enrollment_ages_5_17'': 160.0, ''total_free_meal_count_ages_5_17'': 66.0, ''total_frpm_count_ages_5_17'': 68.0}, {''school'': ''Alameda County Community'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''school type'': ''County Community'', ''charter school (y/n)'': 0, ''total_enrollment_k12'': 277.0, ''total_free_meal_count_k12'': 190.0, ''total_frpm_count_k12'': 223.0, ''total_enrollment_ages_5_17'': 221.0, ''total_free_meal_count_ages_5_17'': 145.0, ''total_frpm_count_ages_5_17'': 172.0}, {''school'': ''Cox Academy'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''school type'': ''Elementary Schools (Public)'', ''charter school (y/n)'': 1, ''total_enrollment_k12'': 597.0, ''total_free_meal_count_k12'': 493.0, ''total_frpm_count_k12'': 557.0, ''total_enrollment_ages_5_17'': 586.0, ''total_free_meal_count_ages_5_17'': 483.0, ''total_frpm_count_ages_5_17'': 546.0}, {''school'': ''Lazear Charter Academy'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''school type'': ''Element ...
#
# var margin = {top: 20, right: 30, bottom: 40, left: 40},
#     width = 800 - margin.left - margin.right,
#     height = 600 - margin.top - margin.bottom;
#
# var svg = d3.select(''#student-demographics'')
#     .append(''svg'')
#     .attr(''width'', width + margin.left + margin.right)
#     .attr(''height'', height + margin.top + margin.bottom)
#   .append(''g'')
#     .attr(''transform'', ''translate('' + margin.left + '','' + margin.top + '')'');
#
# var x = d3.scaleBand()
#     .domain(data.map(d => d.school))
#     .range([0, width])
#     .padding(0.1);
#
# var y = d3.scaleLinear()
#     .domain([0, d3.max(data, d => d.total_enrollment_k12)])
#     .nice()
#     .range([height, 0]);
#
# svg.append(''g'')
#     .selectAll(''.bar'')
#     .data(data)
#     .enter().append(''rect'')
#       .attr(''class'', ''bar'')
#       .attr(''x'', d => x(d.school))
#       .attr(''y'', d => y(d.total_enrollment_k12))
#       .attr(''width'', x.bandwidth())
#       .attr(''height'', d => height - y(d.total_enrollment_k12))
#       .attr(''fill'', ''#69b3a2'');
#
# svg.append(''g'')
#     .attr(''class'', ''x-axis'')
#     .attr(''transform'', ''translate(0,'' + height + '')'')
#     .call(d3.axisBottom(x).tickFormat(d => d.substring(0, 10))); // Shorten school names for x-axis
#
# svg.append(''g'')
#     .attr(''class'', ''y-axis'')
#     .call(d3.axisLeft(y));
#
# svg.append(''text'')
#     .attr(''class'', ''x label'')
#     .attr(''x'', width / 2)
#     .attr(''y'', height + margin.bottom - 10)
#     .style(''text-anchor'', ''middle'')
#     .text(''Schools'');
#
# svg.append(''text'')
#     .attr(''class'', ''y label'')
#     .attr(''transform'', ''rotate(-90)'')
#     .attr(''y'', -margin.left + 20)
#     .attr(''x'', -height / 2)
#     .style(''text-anchor'', ''middle'')
#     .text(''Total Enrollment K-12'');
#
# </script>' where kpi_uid='019cf690-5e24-4bef-98d2-b8dd716cee12'
# INFO:root:find obj in kpis by 316304d0-0836-4945-adac-631660741f51
# INFO:root:find objs in kpis by kpi_uid='316304d0-0836-4945-adac-631660741f51'
# INFO:root:fetch select * from kpis where kpi_uid='316304d0-0836-4945-adac-631660741f51' with nrows:1
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:llm retunr=DIV_HTML_CODE="<div id='schools-by-region' style='width: 600px; height: 400px;'></div>\n<script src='https://d3js.org/d3.v7.min.js'></script>\n<script>\nvar data = [{'county': 'Alameda', 'number_of_schools': 726}, {'county': 'Alpine', 'number_of_schools': 15}, {'county': 'Amador', 'number_of_schools': 36}, {'county': 'Butte', 'number_of_schools': 157}, {'county': 'Calaveras', 'number_of_schools': 44}, {'county': 'Colusa', 'number_of_schools': 33}, {'county': 'Contra Costa', 'number_of_schools': 443}, {'county': 'Del Norte', 'number_of_schools': 26}, {'county': 'El Dorado', 'number_of_schools': 109}, {'county': 'Fresno', 'number_of_schools': 553}];\n\nvar margin = {top: 20, right: 30, bottom: 40, left: 40},\n    width = 600 - margin.left - margin.right,\n    height = 400 - margin.top - margin.bottom;\n\nvar svg = d3.select('#schools-by-region')\n    .append('svg')\n    .attr('width', width + margin.left + margin.right)\n    .attr('height', height + margin.top + margin.bottom)\n  .append('g')\n    .attr('transform', 'translate(' + margin.left + ',' + margin.top + ')');\n\nvar x = d3.scaleBand()\n    .domain(data.map(function(d) { return d.county; }))\n    .range([0, width])\n    .padding(0.1);\n\nvar y = d3.scaleLinear()\n    .domain([0, d3.max(data, function(d) { return d.number_of_schools; })])\n    .nice()\n    .range([height, 0]);\n\nsvg.append('g')\n    .selectAll('.bar')\n    .data(data)\n    .enter().append('rect')\n      .attr('class', 'bar')\n      .attr('x', function(d) { return x(d.county); })\n      .attr('y', function(d) { return y(d.number_of_schools); })\n      .attr('width', x.bandwidth())\n      .attr('height', function(d) { return height - y(d.number_of_schools); })\n      .attr('fill', '#69b3a2');\n\nsvg.append('g')\n    .attr('class', 'x-axis')\n    .attr('transform', 'translate(0,' + height + ')')\n    .call(d3.axisBottom(x));\n\nsvg.append('g')\n    .attr('class', 'y-axis')\n    .call(d3.axisLeft(y));\n\nsvg.append('text')\n    .attr('transform', 'rotate(-90)')\n    .attr('y', 0 - margin.left + 20)\n    .attr('x', 0 - (height / 2))\n    .attr('dy', '1em')\n    .attr('text-anchor', 'middle')\n    .text('Number of Schools');\n\nsvg.append('text')\n    .attr('transform', 'translate(' + (width / 2) + ' ,' + (height + margin.bottom - 10) + ')')\n    .attr('text-anchor', 'middle')\n    .text('County');\n</script>" visualization_type='Bar Chart'
# INFO:root:executing update kpis SET sql_vis='<div id=''schools-by-region'' style=''width: 600px; height: 400px;''></div>
# <script src=''https://d3js.org/d3.v7.min.js''></script>
# <script>
# var data = [{''county'': ''Alameda'', ''number_of_schools'': 726}, {''county'': ''Alpine'', ''number_of_schools'': 15}, {''county'': ''Amador'', ''number_of_schools'': 36}, {''county'': ''Butte'', ''number_of_schools'': 157}, {''county'': ''Calaveras'', ''number_of_schools'': 44}, {''county'': ''Colusa'', ''number_of_schools'': 33}, {''county'': ''Contra Costa'', ''number_of_schools'': 443}, {''county'': ''Del Norte'', ''number_of_schools'': 26}, {''county'': ''El Dorado'', ''number_of_schools'': 109}, {''county'': ''Fresno'', ''number_of_schools'': 553}];
#
# var margin = {top: 20, right: 30, bottom: 40, left: 40},
#     width = 600 - margin.left - margin.right,
#     height = 400 - margin.top - margin.bottom;
#
# var svg = d3.select(''#schools-by-region'')
#     .append(''svg'')
#     .attr(''width'', width + margin.left + margin.right)
#     .attr(''height'', height + margin.top + margin.bottom)
#   .append(''g'')
#     .attr(''transform'', ''translate('' + margin.left + '','' + margin.top + '')'');
#
# var x = d3.scaleBand()
#     .domain(data.map(function(d) { return d.county; }))
#     .range([0, width])
#     .padding(0.1);
#
# var y = d3.scaleLinear()
#     .domain([0, d3.max(data, function(d) { return d.number_of_schools; })])
#     .nice()
#     .range([height, 0]);
#
# svg.append(''g'')
#     .selectAll(''.bar'')
#     .data(data)
#     .enter().append(''rect'')
#       .attr(''class'', ''bar'')
#       .attr(''x'', function(d) { return x(d.county); })
#       .attr(''y'', function(d) { return y(d.number_of_schools); })
#       .attr(''width'', x.bandwidth())
#       .attr(''height'', function(d) { return height - y(d.number_of_schools); })
#       .attr(''fill'', ''#69b3a2'');
#
# svg.append(''g'')
#     .attr(''class'', ''x-axis'')
#     .attr(''transform'', ''translate(0,'' + height + '')'')
#     .call(d3.axisBottom(x));
#
# svg.append(''g'')
#     .attr(''class'', ''y-axis'')
#     .call(d3.axisLeft(y));
#
# svg.append(''text'')
#     .attr(''transform'', ''rotate(-90)'')
#     .attr(''y'', 0 - margin.left + 20)
#     .attr(''x'', 0 - (height / 2))
#     .attr(''dy'', ''1em'')
#     .attr(''text-anchor'', ''middle'')
#     .text(''Number of Schools'');
#
# svg.append(''text'')
#     .attr(''transform'', ''translate('' + (width / 2) + '' ,'' + (height + margin.bottom - 10) + '')'')
#     .attr(''text-anchor'', ''middle'')
#     .text(''County'');
# </script>' where kpi_uid='316304d0-0836-4945-adac-631660741f51'
# INFO:root:find obj in kpis by 2f2c68da-4118-42c1-adc9-02ef7b7c0f1e
# INFO:root:find objs in kpis by kpi_uid='2f2c68da-4118-42c1-adc9-02ef7b7c0f1e'
# INFO:root:fetch select * from kpis where kpi_uid='2f2c68da-4118-42c1-adc9-02ef7b7c0f1e' with nrows:1
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:llm retunr=DIV_HTML_CODE="<div id='school-participation-chart' style='width: 600px; height: 400px;'></div>\n<script src='https://d3js.org/d3.v7.min.js'></script>\n<script>\n    const data = [{'NumberOfSchoolsParticipating': 9936}];\n\n    const width = 600;\n    const height = 400;\n    const margin = {top: 20, right: 30, bottom: 40, left: 40};\n\n    const svg = d3.select('#school-participation-chart')\n        .append('svg')\n        .attr('width', width)\n        .attr('height', height);\n\n    const x = d3.scaleBand()\n        .domain(['Schools'])\n        .range([margin.left, width - margin.right])\n        .padding(0.1);\n\n    const y = d3.scaleLinear()\n        .domain([0, d3.max(data, d => d.NumberOfSchoolsParticipating)]).nice()\n        .range([height - margin.bottom, margin.top]);\n\n    svg.append('g')\n        .attr('fill', 'steelblue')\n        .selectAll('rect')\n        .data(data)\n        .enter()\n        .append('rect')\n        .attr('x', 'Schools')\n        .attr('y', d => y(d.NumberOfSchoolsParticipating))\n        .attr('height', d => y(0) - y(d.NumberOfSchoolsParticipating))\n        .attr('width', x.bandwidth());\n\n    svg.append('g')\n        .attr('transform', `translate(0,${height - margin.bottom})`)\n        .call(d3.axisBottom(x));\n\n    svg.append('g')\n        .attr('transform', `translate(${margin.left},0)`)\n        .call(d3.axisLeft(y));\n\n    svg.append('text')\n        .attr('x', width / 2)\n        .attr('y', margin.top)\n        .attr('text-anchor', 'middle')\n        .text('Number of Schools Participating in Free and Reduced Price Meal Programs');\n\n    svg.append('text')\n        .attr('x', width / 2)\n        .attr('y', height - margin.bottom + 30)\n        .attr('text-anchor', 'middle')\n        .text('Schools');\n\n    svg.append('text')\n        .attr('transform', 'rotate(-90)')\n        .attr('y', margin.left - 30)\n        .attr('x', -height / 2)\n        .attr('text-anchor', 'middle')\n        .text('Number of Schools');\n</script>" visualization_type='Bar Chart'
# INFO:root:executing update kpis SET sql_vis='<div id=''school-participation-chart'' style=''width: 600px; height: 400px;''></div>
# <script src=''https://d3js.org/d3.v7.min.js''></script>
# <script>
#     const data = [{''NumberOfSchoolsParticipating'': 9936}];
#
#     const width = 600;
#     const height = 400;
#     const margin = {top: 20, right: 30, bottom: 40, left: 40};
#
#     const svg = d3.select(''#school-participation-chart'')
#         .append(''svg'')
#         .attr(''width'', width)
#         .attr(''height'', height);
#
#     const x = d3.scaleBand()
#         .domain([''Schools''])
#         .range([margin.left, width - margin.right])
#         .padding(0.1);
#
#     const y = d3.scaleLinear()
#         .domain([0, d3.max(data, d => d.NumberOfSchoolsParticipating)]).nice()
#         .range([height - margin.bottom, margin.top]);
#
#     svg.append(''g'')
#         .attr(''fill'', ''steelblue'')
#         .selectAll(''rect'')
#         .data(data)
#         .enter()
#         .append(''rect'')
#         .attr(''x'', ''Schools'')
#         .attr(''y'', d => y(d.NumberOfSchoolsParticipating))
#         .attr(''height'', d => y(0) - y(d.NumberOfSchoolsParticipating))
#         .attr(''width'', x.bandwidth());
#
#     svg.append(''g'')
#         .attr(''transform'', `translate(0,${height - margin.bottom})`)
#         .call(d3.axisBottom(x));
#
#     svg.append(''g'')
#         .attr(''transform'', `translate(${margin.left},0)`)
#         .call(d3.axisLeft(y));
#
#     svg.append(''text'')
#         .attr(''x'', width / 2)
#         .attr(''y'', margin.top)
#         .attr(''text-anchor'', ''middle'')
#         .text(''Number of Schools Participating in Free and Reduced Price Meal Programs'');
#
#     svg.append(''text'')
#         .attr(''x'', width / 2)
#         .attr(''y'', height - margin.bottom + 30)
#         .attr(''text-anchor'', ''middle'')
#         .text(''Schools'');
#
#     svg.append(''text'')
#         .attr(''transform'', ''rotate(-90)'')
#         .attr(''y'', margin.left - 30)
#         .attr(''x'', -height / 2)
#         .attr(''text-anchor'', ''middle'')
#         .text(''Number of Schools'');
# </script>' where kpi_uid='2f2c68da-4118-42c1-adc9-02ef7b7c0f1e'
# INFO:root:find obj in kpis by 824b96a4-b476-407b-8334-89ebb8cf3080
# INFO:root:find objs in kpis by kpi_uid='824b96a4-b476-407b-8334-89ebb8cf3080'
# INFO:root:fetch select * from kpis where kpi_uid='824b96a4-b476-407b-8334-89ebb8cf3080' with nrows:1
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:llm retunr=DIV_HTML_CODE="<div id='school-demographics' style='width: 600px; height: 400px;'></div>\n<script src='https://d3js.org/d3.v7.min.js'></script>\n<script>\n    // Sample data for School Demographics by Ethnicity and Income Level\n    const data = [\n        { ethnicity: 'White', lowIncome: 30, middleIncome: 50, highIncome: 20 },\n        { ethnicity: 'Black', lowIncome: 40, middleIncome: 30, highIncome: 30 },\n        { ethnicity: 'Hispanic', lowIncome: 50, middleIncome: 40, highIncome: 10 },\n        { ethnicity: 'Asian', lowIncome: 20, middleIncome: 60, highIncome: 20 }\n    ];\n\n    const margin = { top: 20, right: 30, bottom: 40, left: 40 },\n          width = 600 - margin.left - margin.right,\n          height = 400 - margin.top - margin.bottom;\n\n    const svg = d3.select('#school-demographics')\n        .append('svg')\n        .attr('width', width + margin.left + margin.right)\n        .attr('height', height + margin.top + margin.bottom)\n      .append('g')\n        .attr('transform', `translate(${margin.left},${margin.top})`);\n\n    const x = d3.scaleBand()\n        .domain(data.map(d => d.ethnicity))\n        .range([0, width])\n        .padding(0.1);\n\n    const y = d3.scaleLinear()\n        .domain([0, 100])\n        .nice()\n        .range([height, 0]);\n\n    svg.append('g')\n        .attr('class', 'x-axis')\n        .attr('transform', `translate(0,${height})`)\n        .call(d3.axisBottom(x));\n\n    svg.append('g')\n        .attr('class', 'y-axis')\n        .call(d3.axisLeft(y));\n\n    const color = d3.scaleOrdinal()\n        .domain(['lowIncome', 'middleIncome', 'highIncome'])\n        .range(['#ff9999', '#66b3ff', '#99ff99']);\n\n    const stack = d3.stack()\n        .keys(['lowIncome', 'middleIncome', 'highIncome']);\n\n    const series = stack(data);\n\n    svg.selectAll('.layer')\n        .data(series)\n      .enter().append('g')\n        .attr('class', 'layer')\n        .attr('fill', d => color(d.key))\n      .append('path')\n        .attr('d', d3.area()\n            .x(d => x(d.data.ethnicity))\n            .y0(d => y(d[0]))\n            .y1(d => y(d[1]))\n        );\n\n    // Add legend\n    const legend = svg.selectAll('.legend')\n        .data(color.domain())\n      .enter().append('g')\n        .attr('class', 'legend')\n        .attr('transform', (d, i) => `translate(0,${i * 20})`);\n\n    legend.append('rect')\n        .attr('x', width - 18)\n        .attr('width', 18)\n        .attr('height', 18)\n        .attr('fill', color);\n\n    legend.append('text')\n        .attr('x', width - 24)\n        .attr('y', 9)\n        .attr('dy', '0.35em')\n        .style('text-anchor', 'end')\n        .text(d => d);\n\n    // Add axis labels\n    svg.append('text')\n        .attr('transform', 'rotate(-90)')\n        .attr('y', 0 - margin.left)\n        .attr('x', 0 - (height / 2))\n        .attr('dy', '1em')\n        .style('text-anchor', 'middle')\n        .text('Percentage (%)');\n\n    svg.append('text')\n        .attr('x', width / 2)\n        .attr('y', height + margin.bottom - 10)\n        .style('text-anchor', 'middle')\n        .text('Ethnicity');\n</script>" visualization_type='Stacked Area Chart'
# INFO:root:executing update kpis SET sql_vis='<div id=''school-demographics'' style=''width: 600px; height: 400px;''></div>
# <script src=''https://d3js.org/d3.v7.min.js''></script>
# <script>
#     // Sample data for School Demographics by Ethnicity and Income Level
#     const data = [
#         { ethnicity: ''White'', lowIncome: 30, middleIncome: 50, highIncome: 20 },
#         { ethnicity: ''Black'', lowIncome: 40, middleIncome: 30, highIncome: 30 },
#         { ethnicity: ''Hispanic'', lowIncome: 50, middleIncome: 40, highIncome: 10 },
#         { ethnicity: ''Asian'', lowIncome: 20, middleIncome: 60, highIncome: 20 }
#     ];
#
#     const margin = { top: 20, right: 30, bottom: 40, left: 40 },
#           width = 600 - margin.left - margin.right,
#           height = 400 - margin.top - margin.bottom;
#
#     const svg = d3.select(''#school-demographics'')
#         .append(''svg'')
#         .attr(''width'', width + margin.left + margin.right)
#         .attr(''height'', height + margin.top + margin.bottom)
#       .append(''g'')
#         .attr(''transform'', `translate(${margin.left},${margin.top})`);
#
#     const x = d3.scaleBand()
#         .domain(data.map(d => d.ethnicity))
#         .range([0, width])
#         .padding(0.1);
#
#     const y = d3.scaleLinear()
#         .domain([0, 100])
#         .nice()
#         .range([height, 0]);
#
#     svg.append(''g'')
#         .attr(''class'', ''x-axis'')
#         .attr(''transform'', `translate(0,${height})`)
#         .call(d3.axisBottom(x));
#
#     svg.append(''g'')
#         .attr(''class'', ''y-axis'')
#         .call(d3.axisLeft(y));
#
#     const color = d3.scaleOrdinal()
#         .domain([''lowIncome'', ''middleIncome'', ''highIncome''])
#         .range([''#ff9999'', ''#66b3ff'', ''#99ff99'']);
#
#     const stack = d3.stack()
#         .keys([''lowIncome'', ''middleIncome'', ''highIncome'']);
#
#     const series = stack(data);
#
#     svg.selectAll(''.layer'')
#         .data(series)
#       .enter().append(''g'')
#         .attr(''class'', ''layer'')
#         .attr(''fill'', d => color(d.key))
#       .append(''path'')
#         .attr(''d'', d3.area()
#             .x(d => x(d.data.ethnicity))
#             .y0(d => y(d[0]))
#             .y1(d => y(d[1]))
#         );
#
#     // Add legend
#     const legend = svg.selectAll(''.legend'')
#         .data(color.domain())
#       .enter().append(''g'')
#         .attr(''class'', ''legend'')
#         .attr(''transform'', (d, i) => `translate(0,${i * 20})`);
#
#     legend.append(''rect'')
#         .attr(''x'', width - 18)
#         .attr(''width'', 18)
#         .attr(''height'', 18)
#         .attr(''fill'', color);
#
#     legend.append(''text'')
#         .attr(''x'', width - 24)
#         .attr(''y'', 9)
#         .attr(''dy'', ''0.35em'')
#         .style(''text-anchor'', ''end'')
#         .text(d => d);
#
#     // Add axis labels
#     svg.append(''text'')
#         .attr(''transform'', ''rotate(-90)'')
#         .attr(''y'', 0 - margin.left)
#         .attr(''x'', 0 - (height / 2))
#         .attr(''dy'', ''1em'')
#         .style(''text-anchor'', ''middle'')
#         .text(''Percentage (%)'');
#
#     svg.append(''text'')
#         .attr(''x'', width / 2)
#         .attr(''y'', height + margin.bottom - 10)
#         .style(''text-anchor'', ''middle'')
#         .text(''Ethnicity'');
# </script>' where kpi_uid='824b96a4-b476-407b-8334-89ebb8cf3080'
# INFO:root:find obj in kpis by a1996297-83ec-4cb2-a10b-45263c8c65ac
# INFO:root:find objs in kpis by kpi_uid='a1996297-83ec-4cb2-a10b-45263c8c65ac'
# INFO:root:fetch select * from kpis where kpi_uid='a1996297-83ec-4cb2-a10b-45263c8c65ac' with nrows:1
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:llm retunr=DIV_HTML_CODE="<div id='student-performance-trends' style='width: 800px; height: 500px;'></div>\n<script src='https://d3js.org/d3.v7.min.js'></script>\n<script>\n    const data = [{'school_id': '01611190130609', 'school_name': 'Alameda Community Learning Center', 'county_name': 'Alameda', 'avg_math_score': '593.0000', 'avg_reading_score': '575.0000', 'avg_writing_score': '581.0000', 'total_enrollment_12th_grade': '26'}, {'school_id': '01611190130229', 'school_name': 'Alameda High', 'county_name': 'Alameda', 'avg_math_score': '573.0000', 'avg_reading_score': '543.0000', 'avg_writing_score': '543.0000', 'total_enrollment_12th_grade': '465'}, {'school_id': '01611190106401', 'school_name': 'Alameda Science and Technology Institute', 'county_name': 'Alameda', 'avg_math_score': '590.0000', 'avg_reading_score': '562.0000', 'avg_writing_score': '555.0000', 'total_enrollment_12th_grade': '36'}, {'school_id': '01611270130450', 'school_name': 'Albany High', 'county_name': 'Alameda', 'avg_math_score': '599.0000', 'avg_reading_score': '572.0000', 'avg_writing_score': '574.0000', 'total_enrollment_12th_grade': '273'}, {'school_id': '01611190130625', 'school_name': 'Alternatives in Action', 'county_name': 'Alameda', 'avg_math_score': '350.0000', 'avg_reading_score': '352.0000', 'avg_writing_score': '343.0000', 'total_enrollment_12th_grade': '41'}, {'school_id': '01751010130583', 'school_name': 'Amador Valley High', 'county_name': 'Alameda', 'avg_math_score': '614.0000', 'avg_reading_score': '596.0000', 'avg_writing_score': '592.0000', 'total_enrollment_12th_grade': '650'}, {'school_id': '01611760130062', 'school_name': 'American High', 'county_name': 'Alameda', 'avg_math_score': '608.0000', 'avg_reading_score': '573.0000', 'avg_writing_score': '592.0000', 'total_enrollment_12th_grade': '457'}, {'school_id': '01612590111856', 'school_name': 'American Indian Public High', 'county_name': 'Alameda', 'avg_math_score': '603.0000', 'avg_reading_score': '505.0000', 'avg_writing_score': '514.0000', 'total_enrollment_12th_grade': '27'}, {'school_id': '01612590115238', 'school_name': 'ARISE High', 'county_name': 'Alameda', 'avg_math_score': '367.0000', 'avg_reading_score': '359.0000', 'avg_writing_score': '369.0000', 'total_enrollment_12th_grade': '36'}, {'school_id': '01613090130849', 'school_name': 'Arroyo High', 'county_name': 'Alameda', 'avg_math_score': '521.0000', 'avg_reading_score': '489.0000', 'avg_writing_score': '479.0000', 'total_enrollment_12th_grade': '415'}];\n\n    const margin = {top: 20, right: 30, bottom: 40, left: 40},\n          width = 800 - margin.left - margin.right,\n          height = 500 - margin.top - margin.bottom;\n\n    const svg = d3.select('#student-performance-trends')\n        .append('svg')\n        .attr('width', width + margin.left + margin.right)\n        .attr('height', height + margin.top + margin.bottom)\n      .append('g')\n        .attr('transform', `translate(${margin.left},${margin.top})`);\n\n    const x = d3.scaleBand()\n        .domain(data.map(d => d.school_name))\n        .range([0, width])\n        .padding(0.1);\n\n    const y = d3.scaleLinear()\n        .domain([0, d3.max(data, d => Math.max(d.avg_math_score, d.avg_reading_score, d.avg_writing_score))])\n        .nice()\n        .range([height, 0]);\n\n    svg.append('g')\n        .selectAll('.bar')\n        .data(data)\n        .enter().append('g')\n        .attr('class', 'bar')\n        .attr('transform', d => `translate(${x(d.school_name)},0)`)\n        .selectAll('rect')\n        .data(d => [d.avg_math_score, d.avg_reading_score, d.avg_writing_score])\n        .enter().append('rect')\n        .attr('x', (d, i) => i * (x.bandwidth() / 3))\n        .attr('y', d => y(d))\n        .attr('width', x.bandwidth() / 3 - 1)\n        .attr('height', d => height - y(d))\n        .attr('fill', (d, i) => i === 0 ? 'steelblue' : i === 1 ? 'orange' : 'green');\n\n    svg.append('g')\n        .attr('class', 'x-axis')\n        .attr('transfor ...
# INFO:root:executing update kpis SET sql_vis='<div id=''student-performance-trends'' style=''width: 800px; height: 500px;''></div>
# <script src=''https://d3js.org/d3.v7.min.js''></script>
# <script>
#     const data = [{''school_id'': ''01611190130609'', ''school_name'': ''Alameda Community Learning Center'', ''county_name'': ''Alameda'', ''avg_math_score'': ''593.0000'', ''avg_reading_score'': ''575.0000'', ''avg_writing_score'': ''581.0000'', ''total_enrollment_12th_grade'': ''26''}, {''school_id'': ''01611190130229'', ''school_name'': ''Alameda High'', ''county_name'': ''Alameda'', ''avg_math_score'': ''573.0000'', ''avg_reading_score'': ''543.0000'', ''avg_writing_score'': ''543.0000'', ''total_enrollment_12th_grade'': ''465''}, {''school_id'': ''01611190106401'', ''school_name'': ''Alameda Science and Technology Institute'', ''county_name'': ''Alameda'', ''avg_math_score'': ''590.0000'', ''avg_reading_score'': ''562.0000'', ''avg_writing_score'': ''555.0000'', ''total_enrollment_12th_grade'': ''36''}, {''school_id'': ''01611270130450'', ''school_name'': ''Albany High'', ''county_name'': ''Alameda'', ''avg_math_score'': ''599.0000'', ''avg_reading_score'': ''572.0000'', ''avg_writing_score'': ''574.0000'', ''total_enrollment_12th_grade'': ''273''}, {''school_id'': ''01611190130625'', ''school_name'': ''Alternatives in Action'', ''county_name'': ''Alameda'', ''avg_math_score'': ''350.0000'', ''avg_reading_score'': ''352.0000'', ''avg_writing_score'': ''343.0000'', ''total_enrollment_12th_grade'': ''41''}, {''school_id'': ''01751010130583'', ''school_name'': ''Amador Valley High'', ''county_name'': ''Alameda'', ''avg_math_score'': ''614.0000'', ''avg_reading_score'': ''596.0000'', ''avg_writing_score'': ''592.0000'', ''total_enrollment_12th_grade'': ''650''}, {''school_id'': ''01611760130062'', ''school_name'': ''American High'', ''county_name'': ''Alameda'', ''avg_math_score'': ''608.0000'', ''avg_reading_score'': ''573.0000'', ''avg_writing_score'': ''592.0000'', ''total_enrollment_12th_grade'': ''457''}, {''school_id'': ''01612590111856'', ''school_name'': ''American Indian Public High'', ''county_name'': ''Alameda'', ''avg_math_score'': ''603.0000'', ''avg_reading_score'': ''505.0000'', ''avg_writing_score'': ''514.0000'', ''total_enrollment_12th_grade'': ''27''}, {''school_id'': ''01612590115238'', ''school_name'': ''ARISE High'', ''county_name'': ''Alameda'', ''avg_math_score'': ''367.0000'', ''avg_reading_score'': ''359.0000'', ''avg_writing_score'': ''369.0000'', ''total_enrollment_12th_grade'': ''36''}, {''school_id'': ''01613090130849'', ''school_name'': ''Arroyo High'', ''county_name'': ''Alameda'', ''avg_math_score'': ''521.0000'', ''avg_reading_score'': ''489.0000'', ''avg_writing_score'': ''479.0000'', ''total_enrollment_12th_grade'': ''415''}];
#
#     const margin = {top: 20, right: 30, bottom: 40, left: 40},
#           width = 800 - margin.left - margin.right,
#           height = 500 - margin.top - margin.bottom;
#
#     const svg = d3.select(''#student-performance-trends'')
#         .append(''svg'')
#         .attr(''width'', width + margin.left + margin.right)
#         .attr(''height'', height + margin.top + margin.bottom)
#       .append(''g'')
#         .attr(''transform'', `translate(${margin.left},${margin.top})`);
#
#     const x = d3.scaleBand()
#         .domain(data.map(d => d.school_name))
#         .range([0, width])
#         .padding(0.1);
#
#     const y = d3.scaleLinear()
#         .domain([0, d3.max(data, d => Math.max(d.avg_math_score, d.avg_reading_score, d.avg_writing_score))])
#         .nice()
#         .range([height, 0]);
#
#     svg.append(''g'')
#         .selectAll(''.bar'')
#         .data(data)
#         .enter().append(''g'')
#         .attr(''class'', ''bar'')
#         .attr(''transform'', d => `translate(${x(d.school_name)},0)`)
#         .selectAll(''rect'')
#         .data(d => [d.avg_math_score, d.avg_reading_score, d.avg_writing_score])
#         .enter().append(''rect'')
#         .attr(''x'', (d, i) => i * (x.bandwidth() / 3))
#         .attr(''y'', d => y(d))
#         .attr(''width'', x.bandwidth() / 3 - 1)
#         .attr(''height'', d => height - y(d))
#         .attr(''fill'', (d, i) => i === 0 ? ''steelblue'' : i === 1 ? ''orange'' : ''green'');
#
#     svg.append(''g'')
#         .attr(''class'', ''x-axis'')
#         .attr(''transform'', `translate(0,${height})`)
#         .call(d3.axisBottom(x));
#
#     svg.append(''g'')
#         .attr(''class'', ''y-axis'')
#         .call(d3.axisLeft(y));
#
#     svg.append(''text'')
#         .attr(''transform'', ''rotate(-90)'')
#         .attr(''y'', 0 - margin.left)
#         .attr(''x'', 0 - (height / 2))
#         .attr(''dy'', ''1em'')
#         .attr(''text-anchor'', ''middle'')
#         .text(''Scores'');
#
#     svg.append(''text'')
#         .attr(''x'', width / 2)
#         .attr(''y'', height + margin.bottom - 10)
#         .attr(''text-anchor'', ''middle'')
#         .text(''Schools'');
#
#     const legend = svg.append(''g'')
#         .attr(''transform'', `translate(${width - 100}, 0)`);
#
#     legend.selectAll(''.legend-item'')
#         .data([''Math'', ''Reading'', ''Writing''])
#         .enter().append(''rect'')
#         .attr(''class'', ''legend-item'')
#         .attr(''x'', 0)
#         .attr(''y'', (d, i) => i * 20)
#         .attr(''width'', 18)
#         .attr(''height'', 18)
#         .attr(''fill'', (d, i) => i === 0 ? ''steelblue'' : i === 1 ? ''orange'' : ''green'');
#
#     legend.selectAll(''.legend-text'')
#         .data([''Math'', ''Reading'', ''Writing''])
#         .enter().append(''text'')
#         .attr(''x'', 25)
#         .attr(''y'', (d, i) => i * 20 + 15)
#         .text(d => d);
# </script>' where kpi_uid='a1996297-83ec-4cb2-a10b-45263c8c65ac'
# INFO:root:find obj in kpis by a101994f-8732-4953-85f0-d11db6daf7d8
# INFO:root:find objs in kpis by kpi_uid='a101994f-8732-4953-85f0-d11db6daf7d8'
# INFO:root:fetch select * from kpis where kpi_uid='a101994f-8732-4953-85f0-d11db6daf7d8' with nrows:1
# ...
# <script>
# var data = [{''County'': ''Alameda'', ''District'': ''Alameda County Office of Education'', ''School'': ''Alameda County Community'', ''Total_Schools'': 1, ''Avg_Percent_Eligible_Free_K12'': 0.685920577617328, ''Avg_Percent_Eligible_FRPM_K12'': 0.805054151624549, ''Avg_Percent_Eligible_Free_Ages_5_17'': 0.656108597285068, ''Avg_Percent_Eligible_FRPM_Ages_5_17'': 0.778280542986425}, {''County'': ''Alameda'', ''District'': ''Alameda County Office of Education'', ''School'': ''Alameda County Juvenile Hall/Court'', ''Total_Schools'': 1, ''Avg_Percent_Eligible_Free_K12'': 0.392265193370166, ''Avg_Percent_Eligible_FRPM_K12'': 0.403314917127072, ''Avg_Percent_Eligible_Free_Ages_5_17'': 0.4125, ''Avg_Percent_Eligible_FRPM_Ages_5_17'': 0.425}, {''County'': ''Alameda'', ''District'': ''Alameda County Office of Education'', ''School'': ''Aspire California College Preparatory Academy'', ''Total_Schools'': 1, ''Avg_Percent_Eligible_Free_K12'': 0.549180327868853, ''Avg_Percent_Eligible_FRPM_K12'': 0.717213114754098, ''Avg_Percent_Eligible_Free_Ages_5_17'': 0.556521739130435, ''Avg_Percent_Eligible_FRPM_Ages_5_17'': 0.730434782608696}, {''County'': ''Alameda'', ''District'': ''Alameda County Office of Education'', ''School'': ''Community School for Creative Education'', ''Total_Schools'': 1, ''Avg_Percent_Eligible_Free_K12'': 0.591623036649215, ''Avg_Percent_Eligible_FRPM_K12'': 0.727748691099476, ''Avg_Percent_Eligible_Free_Ages_5_17'': 0.594736842105263, ''Avg_Percent_Eligible_FRPM_Ages_5_17'': 0.731578947368421}, {''County'': ''Alameda'', ''District'': ''Alameda County Office of Education'', ''School'': ''Cox Academy'', ''Total_Schools'': 1, ''Avg_Percent_Eligible_Free_K12'': 0.825795644891122, ''Avg_Percent_Eligible_FRPM_K12'': 0.932998324958124, ''Avg_Percent_Eligible_Free_Ages_5_17'': 0.824232081911263, ''Avg_Percent_Eligible_FRPM_Ages_5_17'': 0.931740614334471}, {''County'': ''Alameda'', ''District'': ''Alameda County Office of Education'', ''School'': ''Envision Academy for Arts & Technology'', ''Total_Schools'': 1, ''Avg_Percent_Eligible_Free_K12'': 0.470886075949367, ''Avg_Percent_Eligible_FRPM_K12'': 0.470886075949367, ''Avg_Percent_Eligible_Free_Ages_5_17'': 0.484042553191489, ''Avg_Percent_Eligible_FRPM_Ages_5_17'': 0.484042553191489}, {''County'': ''Alameda'', ''District'': ''Alameda County Office of Education'', ''School'': ''FAME Public Charter'', ''Total_Schools'': 1, ''Avg_Percent_Eligible_Free_K12'': 0.519779208831647, ''Avg_Percent_Eligible_FRPM_K12'': 0.657773689052438, ''Avg_Percent_Eligible_Free_Ages_5_17'': 0.516822429906542, ''Avg_Percent_Eligible_FRPM_Ages_5_17'': 0.65607476635514}, {''County'': ''Alameda'', ''District'': ''Alameda County Office of Education'', ''School'': ''Lazear Charter Academy'', ''Total_Schools'': 1, ''Avg_Percent_Eligible_Free_K12'': 0.768878718535469, ''Avg_Percent_Eligible_FRPM_K12'': 0.91533180778032, ''Avg_Percent_Eligible_Free_Ages_5_17'': 0.768878718535469, ''Avg_Percent_Eligible_FRPM_Ages_5_17'': 0.91533180778032}, {''County'': ''Alameda'', ''District'': ''Alameda County Office of Education'', ''School'': ''Urban Montessori Charter'', ''Total_Schools'': 1, ''Avg_Percent_Eligible_Free_K12'': 0.290322580645161, ''Avg_Percent_Eligible_FRPM_K12'': 0.362007168458781, ''Avg_Percent_Eligible_Free_Ages_5_17'': 0.285714285714286, ''Avg_Percent_Eligible_FRPM_Ages_5_17'': 0.358974358974359}, {''County'': ''Alameda'', ''District'': ''Alameda County Office of Education'', ''School'': ''Yu Ming Charter'', ''Total_Schools'': 1, ''Avg_Percent_Eligible_Free_K12'': 0.0544747081712062, ''Avg_Percent_Eligible_FRPM_K12'': 0.0817120622568093, ''Avg_Percent_Eligible_Free_Ages_5_17'': 0.0544747081712062, ''Avg_Percent_Eligible_FRPM_Ages_5_17'': 0.0817120622568093}];
#
# var margin = {top: 20, right: 30, bottom: 40, left: 40},
#     width = 800 - margin.left - margin.right,
#     height = 600 - margin.top - margin.bottom;
#
# var svg = d3.select(''#div-school-demographics'').append(''svg'')
#     .attr(''width'', width + margin.left + margin.right)
#     .attr(''height'', height + margin.top + margin.bottom)
#   .append(''g'')
#     .attr(''transform'', ''translate('' + margin.left + '','' + margin.top + '')'');
#
# var x = d3.scaleBand()
#     .domain(data.map(d => d.School))
#     .range([0, width])
#     .padding(0.1);
#
# var y = d3.scaleLinear()
#     .domain([0, 1])
#     .nice()
#     .range([height, 0]);
#
# svg.append(''g'')
#     .selectAll(''.bar'')
#     .data(data)
#     .enter().append(''rect'')
#       .attr(''class'', ''bar'')
#       .attr(''x'', d => x(d.School))
#       .attr(''y'', d => y(d.Avg_Percent_Eligible_Free_K12))
#       .attr(''width'', x.bandwidth())
#       .attr(''height'', d => height - y(d.Avg_Percent_Eligible_Free_K12))
#       .attr(''fill'', ''#69b3a2'');
#
# svg.append(''g'')
#     .attr(''class'', ''x-axis'')
#     .attr(''transform'', ''translate(0,'' + height + '')'')
#     .call(d3.axisBottom(x).tickRotation(45));
#
# svg.append(''g'')
#     .attr(''class'', ''y-axis'')
#     .call(d3.axisLeft(y));
#
# svg.append(''text'')
#     .attr(''transform'', ''rotate(-90)'')
#     .attr(''y'', 0 - margin.left + 20)
#     .attr(''x'', 0 - (height / 2))
#     .attr(''dy'', ''1em'')
#     .attr(''text-anchor'', ''middle'')
#     .text(''Average Percent Eligible for Free K-12'');
#
# svg.append(''text'')
#     .attr(''x'', width / 2)
#     .attr(''y'', height + margin.bottom - 10)
#     .attr(''text-anchor'', ''middle'')
#     .text(''Schools'');
#
# </script>' where kpi_uid='d105c4ae-aafa-4260-bc22-ab4e96abdb26'
# INFO:root:find obj in kpis by 8b64bd1d-436e-4488-9ca7-60032fe675ba
# INFO:root:find objs in kpis by kpi_uid='8b64bd1d-436e-4488-9ca7-60032fe675ba'
# INFO:root:fetch select * from kpis where kpi_uid='8b64bd1d-436e-4488-9ca7-60032fe675ba' with nrows:1
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:llm retunr=DIV_HTML_CODE="<div id='school-info-completeness' style='width: 800px; height: 400px;'></div>\n<script src='https://d3js.org/d3.v7.min.js'></script>\n<script>\nvar data = [{'CDSCode': '01100170109835', 'school': 'FAME Public Charter', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'charter': 1, 'ncesdist_count': 1, 'ncesschool_count': 1, 'street_count': 1, 'city_count': 1, 'zip_count': 1, 'phone_count': 0, 'website_count': 0, 'opendate_count': 1, 'statustype_count': 1, 'lastupdate_count': 1}, {'CDSCode': '01100170112607', 'school': 'Envision Academy for Arts & Technology', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'charter': 1, 'ncesdist_count': 1, 'ncesschool_count': 1, 'street_count': 1, 'city_count': 1, 'zip_count': 1, 'phone_count': 1, 'website_count': 1, 'opendate_count': 1, 'statustype_count': 1, 'lastupdate_count': 1}, {'CDSCode': '01100170118489', 'school': 'Aspire California College Preparatory Academy', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'charter': 1, 'ncesdist_count': 1, 'ncesschool_count': 1, 'street_count': 1, 'city_count': 1, 'zip_count': 1, 'phone_count': 0, 'website_count': 1, 'opendate_count': 1, 'statustype_count': 1, 'lastupdate_count': 1}, {'CDSCode': '01100170123968', 'school': 'Community School for Creative Education', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'charter': 1, 'ncesdist_count': 1, 'ncesschool_count': 1, 'street_count': 1, 'city_count': 1, 'zip_count': 1, 'phone_count': 1, 'website_count': 1, 'opendate_count': 1, 'statustype_count': 1, 'lastupdate_count': 1}, {'CDSCode': '01100170124172', 'school': 'Yu Ming Charter', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'charter': 1, 'ncesdist_count': 1, 'ncesschool_count': 1, 'street_count': 1, 'city_count': 1, 'zip_count': 1, 'phone_count': 1, 'website_count': 1, 'opendate_count': 1, 'statustype_count': 1, 'lastupdate_count': 1}, {'CDSCode': '01100170125567', 'school': 'Urban Montessori Charter', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'charter': 1, 'ncesdist_count': 1, 'ncesschool_count': 1, 'street_count': 1, 'city_count': 1, 'zip_count': 1, 'phone_count': 1, 'website_count': 1, 'opendate_count': 1, 'statustype_count': 1, 'lastupdate_count': 1}, {'CDSCode': '01100170130401', 'school': 'Alameda County Juvenile Hall/Court', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'charter': 0, 'ncesdist_count': 1, 'ncesschool_count': 1, 'street_count': 1, 'city_count': 1, 'zip_count': 1, 'phone_count': 1, 'website_count': 1, 'opendate_count': 1, 'statustype_count': 1, 'lastupdate_count': 1}, {'CDSCode': '01100170130419', 'school': 'Alameda County Community', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'charter': 0, 'ncesdist_count': 1, 'ncesschool_count': 1, 'street_count': 1, 'city_count': 1, 'zip_count': 1, 'phone_count': 1, 'website_count': 1, 'opendate_count': 1, 'statustype_count': 1, 'lastupdate_count': 1}, {'CDSCode': '01100176001788', 'school': 'Cox Academy', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'charter': 1, 'ncesdist_count': 1, 'ncesschool_count': 1, 'street_count': 1, 'city_count': 1, 'zip_count': 1, 'phone_count': 1, 'website_count': 1, 'opendate_count': 1, 'statustype_count': 1, 'lastupdate_count': 1}, {'CDSCode': '01100176002000', 'school': 'Lazear Charter Academy', 'county': 'Alameda', 'district': 'Alameda County Office of Education', 'charter': 1, 'ncesdist_count': 1, 'ncesschool_count': 1, 'street_count': 1, 'city_count': 1, 'zip_count': 1, 'phone_count': 1, 'website_count': 1, 'opendate_count': 1, 'statustype_count': 1, 'lastupdate_count': 1}];\n\nvar margin = {top: 20, right: 30, bottom: 40, left: 40},\n    width = 800 - margin.left - margin.right,\n    height = 400 - margin.top - margin.bottom;\n\nvar svg = d3.select('#school-info-completeness')\n    .append('svg' ...
# INFO:root:executing update kpis SET sql_vis='<div id=''school-info-completeness'' style=''width: 800px; height: 400px;''></div>
# <script src=''https://d3js.org/d3.v7.min.js''></script>
# <script>
# var data = [{''CDSCode'': ''01100170109835'', ''school'': ''FAME Public Charter'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''charter'': 1, ''ncesdist_count'': 1, ''ncesschool_count'': 1, ''street_count'': 1, ''city_count'': 1, ''zip_count'': 1, ''phone_count'': 0, ''website_count'': 0, ''opendate_count'': 1, ''statustype_count'': 1, ''lastupdate_count'': 1}, {''CDSCode'': ''01100170112607'', ''school'': ''Envision Academy for Arts & Technology'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''charter'': 1, ''ncesdist_count'': 1, ''ncesschool_count'': 1, ''street_count'': 1, ''city_count'': 1, ''zip_count'': 1, ''phone_count'': 1, ''website_count'': 1, ''opendate_count'': 1, ''statustype_count'': 1, ''lastupdate_count'': 1}, {''CDSCode'': ''01100170118489'', ''school'': ''Aspire California College Preparatory Academy'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''charter'': 1, ''ncesdist_count'': 1, ''ncesschool_count'': 1, ''street_count'': 1, ''city_count'': 1, ''zip_count'': 1, ''phone_count'': 0, ''website_count'': 1, ''opendate_count'': 1, ''statustype_count'': 1, ''lastupdate_count'': 1}, {''CDSCode'': ''01100170123968'', ''school'': ''Community School for Creative Education'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''charter'': 1, ''ncesdist_count'': 1, ''ncesschool_count'': 1, ''street_count'': 1, ''city_count'': 1, ''zip_count'': 1, ''phone_count'': 1, ''website_count'': 1, ''opendate_count'': 1, ''statustype_count'': 1, ''lastupdate_count'': 1}, {''CDSCode'': ''01100170124172'', ''school'': ''Yu Ming Charter'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''charter'': 1, ''ncesdist_count'': 1, ''ncesschool_count'': 1, ''street_count'': 1, ''city_count'': 1, ''zip_count'': 1, ''phone_count'': 1, ''website_count'': 1, ''opendate_count'': 1, ''statustype_count'': 1, ''lastupdate_count'': 1}, {''CDSCode'': ''01100170125567'', ''school'': ''Urban Montessori Charter'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''charter'': 1, ''ncesdist_count'': 1, ''ncesschool_count'': 1, ''street_count'': 1, ''city_count'': 1, ''zip_count'': 1, ''phone_count'': 1, ''website_count'': 1, ''opendate_count'': 1, ''statustype_count'': 1, ''lastupdate_count'': 1}, {''CDSCode'': ''01100170130401'', ''school'': ''Alameda County Juvenile Hall/Court'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''charter'': 0, ''ncesdist_count'': 1, ''ncesschool_count'': 1, ''street_count'': 1, ''city_count'': 1, ''zip_count'': 1, ''phone_count'': 1, ''website_count'': 1, ''opendate_count'': 1, ''statustype_count'': 1, ''lastupdate_count'': 1}, {''CDSCode'': ''01100170130419'', ''school'': ''Alameda County Community'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''charter'': 0, ''ncesdist_count'': 1, ''ncesschool_count'': 1, ''street_count'': 1, ''city_count'': 1, ''zip_count'': 1, ''phone_count'': 1, ''website_count'': 1, ''opendate_count'': 1, ''statustype_count'': 1, ''lastupdate_count'': 1}, {''CDSCode'': ''01100176001788'', ''school'': ''Cox Academy'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''charter'': 1, ''ncesdist_count'': 1, ''ncesschool_count'': 1, ''street_count'': 1, ''city_count'': 1, ''zip_count'': 1, ''phone_count'': 1, ''website_count'': 1, ''opendate_count'': 1, ''statustype_count'': 1, ''lastupdate_count'': 1}, {''CDSCode'': ''01100176002000'', ''school'': ''Lazear Charter Academy'', ''county'': ''Alameda'', ''district'': ''Alameda County Office of Education'', ''charter'': 1, ''ncesdist_count'': 1, ''ncesschool_count'': 1, ''street_count'': 1, ''city_count'': 1, ''zip_count'': 1, ''phone_count'': 1, ''website_count'': 1, ''opendate_count'': 1, ''statustype_count'': 1, ''lastupdate_count'': 1}];
#
# var margin = {top: 20, right: 30, bottom: 40, left: 40},
#     width = 800 - margin.left - margin.right,
#     height = 400 - margin.top - margin.bottom;
#
# var svg = d3.select(''#school-info-completeness'')
#     .append(''svg'')
#     .attr(''width'', width + margin.left + margin.right)
#     .attr(''height'', height + margin.top + margin.bottom)
#   .append(''g'')
#     .attr(''transform'', ''translate('' + margin.left + '','' + margin.top + '')'');
#
# var x = d3.scaleBand()
#     .domain(data.map(d => d.school))
#     .range([0, width])
#     .padding(0.1);
#
# var y = d3.scaleLinear()
#     .domain([0, d3.max(data, d => d.phone_count + d.website_count)])
#     .nice()
#     .range([height, 0]);
#
# svg.append(''g'')
#     .selectAll(''.bar'')
#     .data(data)
#     .enter().append(''rect'')
#       .attr(''class'', ''bar'')
#       .attr(''x'', d => x(d.school))
#       .attr(''y'', d => y(d.phone_count + d.website_count))
#       .attr(''width'', x.bandwidth())
#       .attr(''height'', d => height - y(d.phone_count + d.website_count))
#       .attr(''fill'', ''#69b3a2'');
#
# svg.append(''g'')
#     .attr(''class'', ''x-axis'')
#     .attr(''transform'', ''translate(0,'' + height + '')'')
#     .call(d3.axisBottom(x));
#
# svg.append(''g'')
#     .attr(''class'', ''y-axis'')
#     .call(d3.axisLeft(y));
#
# svg.append(''text'')
#     .attr(''transform'', ''rotate(-90)'')
#     .attr(''y'', 0 - margin.left + 20)
#     .attr(''x'', 0 - (height / 2))
#     .attr(''dy'', ''1em'')
#     .attr(''text-anchor'', ''middle'')
#     .text(''Count of Information Completeness'');
#
# svg.append(''text'')
#     .attr(''transform'', ''translate('' + (width / 2) + '' ,'' + (height + margin.top + 20) + '')'')
#     .attr(''text-anchor'', ''middle'')
#     .text(''Schools'');
# </script>' where kpi_uid='8b64bd1d-436e-4488-9ca7-60032fe675ba'
# INFO:root:find obj in kpis by c6ec35b8-38db-4fd3-81c6-f9f0ca4dae20
# INFO:root:find objs in kpis by kpi_uid='c6ec35b8-38db-4fd3-81c6-f9f0ca4dae20'
# INFO:root:fetch select * from kpis where kpi_uid='c6ec35b8-38db-4fd3-81c6-f9f0ca4dae20' with nrows:1
