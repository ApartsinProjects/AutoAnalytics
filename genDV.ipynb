# %%
import logging,sys


# %reload_ext autoreload
# %autoreload 2
from baseAgent import BaseAgent

# %%
use_cases={
    "education":{"dbname":"acmecollege", "org":"college in US", "application":"Student Information System","platform":"PostgreSQL"},
    "transportation":{"dbname":"acmebus", "org":"public transportation bus company", "application":"telematics solution","platform":"PostgreSQL"},
    "ecommerce": {"dbname":"acmepharm", "org":"online pharmacy", "application":"CRM and inventory management system","platform":"PostgreSQL"}       
}

# %%
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
from metaDB import MetaDB

mdb=MetaDB()
# Out:
# INFO:root:connecting to taskanalytics

# %%
user_info={"user_name":"John","user_role":"Fleet manager"}

org_info={"org_name":"Egged",
          "org_descr":"bus public transportation",
          "org_conn_str":"dbname=''acmebus'' user=''taskanalytics'' password=''leningrad'' host=''localhost'' port=''5432''",
          "org_data_app":"telematics solution"}

# %%
#user_uid=mdb.create_or_update_user(user_info,org_info)

# %%
org_uid='128142f1-ae49-4477-9949-a6b2db76f69a'
mdb.fetch_schema(org_uid)
# Out:
# INFO:root:find obj in orgs by 128142f1-ae49-4477-9949-a6b2db76f69a
# INFO:root:fetchingselect * from orgs where org_uid='128142f1-ae49-4477-9949-a6b2db76f69a'
# INFO:root:fetchingSELECT tablename FROM pg_catalog.pg_tables WHERE schemaname != 'pg_catalog' AND schemaname != 'information_schema'
# INFO:root:fetchingSELECT column_name,data_type FROM information_schema.columns WHERE table_name = 'vehicles'
# INFO:root:executing insert into cols (col_uid,col_name,col_type,table_name,table_org_uid) values ('2ed95196-e1f8-42cd-80ef-cc2468e75046','vehicle_id','uuid','vehicles','128142f1-ae49-4477-9949-a6b2db76f69a'),('d51ae0c4-07c0-4f03-93dc-9f3a860d05a1','year_of_manufacture','integer','vehicles','128142f1-ae49-4477-9949-a6b2db76f69a'),('2c69606f-8db6-444b-a2db-9aad6372e6da','license_plate','character varying','vehicles','128142f1-ae49-4477-9949-a6b2db76f69a'),('40edce25-0440-4017-9baf-b4b9ff476ec0','model','character varying','vehicles','128142f1-ae49-4477-9949-a6b2db76f69a'),('7c68a91f-e31c-4c56-8d7f-02e2516b27a2','manufacturer','character varying','vehicles','128142f1-ae49-4477-9949-a6b2db76f69a')
# INFO:root:fetchingSELECT column_name,data_type FROM information_schema.columns WHERE table_name = 'routes'
# INFO:root:executing insert into cols (col_uid,col_name,col_type,table_name,table_org_uid) values ('768fa21a-8202-4293-88bf-85598b33cc36','route_id','uuid','routes','128142f1-ae49-4477-9949-a6b2db76f69a'),('1c707f5c-e113-485f-b423-5988caaa76a1','distance','double precision','routes','128142f1-ae49-4477-9949-a6b2db76f69a'),('b847109a-90de-4d8b-95a0-198b84521448','route_name','character varying','routes','128142f1-ae49-4477-9949-a6b2db76f69a'),('5c88af5b-a81b-4bc0-ad33-d914bf63d4ac','start_location','character varying','routes','128142f1-ae49-4477-9949-a6b2db76f69a'),('af59f360-5096-4eef-b1fe-a08b3834dafa','end_location','character varying','routes','128142f1-ae49-4477-9949-a6b2db76f69a')
# INFO:root:fetchingSELECT column_name,data_type FROM information_schema.columns WHERE table_name = 'trips'
# INFO:root:executing insert into cols (col_uid,col_name,col_type,table_name,table_org_uid) values ('17edf859-d1b9-4883-a3fe-764431616ef2','trip_id','uuid','trips','128142f1-ae49-4477-9949-a6b2db76f69a'),('1870f83d-4d0e-4b41-a7ba-e8562d95d3be','vehicle_id','uuid','trips','128142f1-ae49-4477-9949-a6b2db76f69a'),('74670b01-d6a1-487b-8f44-15d5d0bee106','route_id','uuid','trips','128142f1-ae49-4477-9949-a6b2db76f69a'),('af41da4e-66f9-460e-99ad-cf1ce40b4346','start_time','timestamp without time zone','trips','128142f1-ae49-4477-9949-a6b2db76f69a'),('58df2645-790f-47e2-8040-1bccc5d00f81','end_time','timestamp without time zone','trips','128142f1-ae49-4477-9949-a6b2db76f69a'),('838a9443-f65f-4e58-b4bf-081a51e073b3','passenger_count','integer','trips','128142f1-ae49-4477-9949-a6b2db76f69a')
# INFO:root:fetchingSELECT column_name,data_type FROM information_schema.columns WHERE table_name = 'vehicle_telemetry'
# INFO:root:executing insert into cols (col_uid,col_name,col_type,table_name,table_org_uid) values ('4dd4737e-8a26-4777-9b73-a978ccc276d6','telemetry_id','uuid','vehicle_telemetry','128142f1-ae49-4477-9949-a6b2db76f69a'),('4dee8c42-54c3-4d8b-a410-ad0dead391bc','vehicle_id','uuid','vehicle_telemetry','128142f1-ae49-4477-9949-a6b2db76f69a'),('7389472d-2a6d-4a81-a336-5075a118ba5b','timestamp','timestamp without time zone','vehicle_telemetry','128142f1-ae49-4477-9949-a6b2db76f69a'),('47e67dbd-10d4-473b-a565-8b5fb82b69aa','latitude','double precision','vehicle_telemetry','128142f1-ae49-4477-9949-a6b2db76f69a'),('9c204e06-e39f-400b-a57f-f87581c5cbd4','longitude','double precision','vehicle_telemetry','128142f1-ae49-4477-9949-a6b2db76f69a'),('dd69fb42-f172-42b4-88a2-e34b8a8fdf75','speed','double precision','vehicle_telemetry','128142f1-ae49-4477-9949-a6b2db76f69a'),('70eb3a2b-8e7c-4e69-863e-c706e16a1efe','fuel_level','double precision','vehicle_telemetry','128142f1-ae49-4477-9949-a6b2db76f69a')
# INFO:root:fetchingSELECT column_name,data_type FROM information_schema.columns WHERE table_name = 'maintenance_records'
# INFO:root:executing insert into cols (col_uid,col_name,col_type,table_name,table_org_uid) values ('21b5af27-4be0-4d4f-a790-5bf1e7a4a828','maintenance_id','uuid','maintenance_records','128142f1-ae49-4477-9949-a6b2db76f69a'),('3edc503d-cd7c-45bc-bf76-f3231c9a86f8','vehicle_id','uuid','maintenance_records','128142f1-ae49-4477-9949-a6b2db76f69a'),('51f3eeb3-7a5d-45f4-8a89-d9955a6249ee','maintenance_date','date','maintenance_records','128142f1-ae49-4477-9949-a6b2db76f69a'),('ac41584e-9b29-4f67-af1a-4ab64734f0e4','cost','double precision','maintenance_records','128142f1-ae49-4477-9949-a6b2db76f69a'),('4feaff6b-201f-43c4-bcd4-ce13ad1996b6','maintenance_type','character varying','maintenance_records','128142f1-ae49-4477-9949-a6b2db76f69a')
