# %%
import logging,sys


# %reload_ext autoreload
# %autoreload 2

# %%
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# %%
user_info={"user_name":"AccMichal","user_role":"insurance analyst"}

org_info={"org_name":"AcmeInsurance",
          "org_descr":"road accident insurance company",
          "org_conn_str":"mysql+pymysql://taskanalytics:leningrad@localhost/accidents",
          "org_data_app":"government road accident tracking system"}

# %%
#user_uid=mdb.create_or_update_user(user_info,org_info)
org_uid='57b5e8a2-5613-49ca-b1c2-1d2a9a4d28e1'
user_uid='d2803e43-2d39-4586-8b70-d49052523902'

# %%
from schemeAnnotator import SchemeAnnotator
sa=SchemeAnnotator()
#sa.fetch_schema(org_uid)
#sa.fetch_schema(org_uid)
sa.enrich_schema(org_uid)
# Out:
# INFO:root:connecting to taskanalytics
# INFO:root:find obj in orgs by 57b5e8a2-5613-49ca-b1c2-1d2a9a4d28e1
# INFO:root:find objs in orgs by org_uid='57b5e8a2-5613-49ca-b1c2-1d2a9a4d28e1'
# INFO:root:fetching select * from orgs where org_uid='57b5e8a2-5613-49ca-b1c2-1d2a9a4d28e1'
# INFO:root:connecting to taskanalytics
# INFO:root:fetching select * from tables where table_org_uid='57b5e8a2-5613-49ca-b1c2-1d2a9a4d28e1'
# INFO:root:fetching select * from cols where col_table_uid='a4a7c0ea-3c2c-4d5d-8197-11898201cca9'
# INFO:root:fetching select * from cols where col_table_uid='d9e10567-9d35-42ef-92c5-f8c01bf538a5'
# INFO:root:fetching select * from cols where col_table_uid='bdf01a21-026a-47ac-bac6-5d41c1a54a5c'
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:find objs in tables by table_name='nesreca' and table_org_uid='57b5e8a2-5613-49ca-b1c2-1d2a9a4d28e1'
# INFO:root:fetching select * from tables where table_name='nesreca' and table_org_uid='57b5e8a2-5613-49ca-b1c2-1d2a9a4d28e1'
# INFO:root:executing update tables SET table_org_uid='57b5e8a2-5613-49ca-b1c2-1d2a9a4d28e1',table_name='nesreca',table_alias='accident',table_desc='This table contains records of road accidents, including details about the accident, location, and conditions at the time of the incident.',table_desc_justification='The table contains detailed information about road accidents, including identifiers, classifications, locations, and conditions.' where table_uid='a4a7c0ea-3c2c-4d5d-8197-11898201cca9'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 5
#       2 sa=SchemeAnnotator()
#       3 #sa.fetch_schema(org_uid)
#       4 #sa.fetch_schema(org_uid)
# ----> 5 sa.enrich_schema(org_uid)
#
# File e:\code\taskAnalytics\schemeAnnotator.py:67, in SchemeAnnotator.enrich_schema(self, org_uid)
#      62 user_msg=f"try to guess useful information about the semantics of tables and columns based on\
#      63     the following basic list fo tables and columns and their types:{scheme_prompt}.\
#      64     Generate descriptions, and meaningful aliases for table and column names based on possible abbreviations and non-English words in their names.\
#      65     Separate descriptive annotation and reasoning on why your guesses are reasonable"
#      66 data_scheme=self.llm.struct_query(sys_msg,user_msg,DataScheme)
# ---> 67 for table in data_scheme.tables: self.update_scheme(table,org_uid)
#
# File e:\code\taskAnalytics\schemeAnnotator.py:75, in update_table_scheme(self, table, org_uid)
#      72 table_info=self.mngDB.find_update_obj("table",f"table_name='{table.table_name}' and table_org_uid='{org_uid}'",table_info)
#      73 for col in table.table_columns:
#      74     col_info={"col_name":col.column_name,"col_units":col.column_units,"col_descr":col.column_description,
# ---> 75               "col_alias":col.column_alias,"col_descr_justification":col.column_annotation_justification,"col_table_uid":table['table_uid']}
#      76     col_info=self.mngDB.find_update_obj("col",f"col_name='{col.column_name}' and col_table_uid='{table['table_uid']}'",col_info)
#
# TypeError: 'TableMetadata' object is not subscriptable
