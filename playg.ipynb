# %%
import logging,sys
# %reload_ext autoreload
# %autoreload 2

from dataSource import DataSource

# %%
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
from dbGen import DBGen
dbg=DBGen().generate_db()
# Out:
# INFO:root:checking for the existence of acmepharm
# INFO:root:list of known dbs=[{'Database': 'accidents'}, {'Database': 'airlines'}, {'Database': 'cdeschool'}, {'Database': 'credit'}, {'Database': 'information_schema'}, {'Database': 'mysql'}, {'Database': 'performance_schema'}, {'Database': 'sys'}]
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:root:scheme=table name:customers table description:Stores information about customers of the online pharmacy. table columns:(column name:customer_id of type:INT description:Unique identifier for each customer.,column name:first_name of type:VARCHAR(50) description:First name of the customer.,column name:last_name of type:VARCHAR(50) description:Last name of the customer.,column name:email of type:VARCHAR(100) description:Email address of the customer.,column name:phone_number of type:VARCHAR(15) description:Contact phone number of the customer.,column name:address of type:VARCHAR(255) description:Shipping address of the customer.);table name:products table description:Stores information about products available in the pharmacy. table columns:(column name:product_id of type:INT description:Unique identifier for each product.,column name:product_name of type:VARCHAR(100) description:Name of the product.,column name:description of type:TEXT description:Description of the product.,column name:price of type:DECIMAL(10, 2) description:Price of the product.,column name:stock_quantity of type:INT description:Quantity of the product available in stock.);table name:orders table description:Stores information about customer orders. table columns:(column name:order_id of type:INT description:Unique identifier for each order.,column name:customer_id of type:INT description:Identifier for the customer who placed the order.,column name:order_date of type:DATETIME description:Date and time when the order was placed.,column name:total_amount of type:DECIMAL(10, 2) description:Total amount for the order.,column name:status of type:VARCHAR(20) description:Current status of the order (e.g., Pending, Shipped, Delivered).);table name:order_items table description:Stores information about items in each order. table columns:(column name:order_item_id of type:INT description:Unique identifier for each order item.,column name:order_id of type:INT description:Identifier for the order to which this item belongs.,column name:product_id of type:INT description:Identifier for the product being ordered.,column name:quantity of type:INT description:Quantity of the product ordered.,column name:price of type:DECIMAL(10, 2) description:Price of the product at the time of order.);table name:inventory table description:Stores information about inventory levels for products. table columns:(column name:inventory_id of type:INT description:Unique identifier for each inventory record.,column name:product_id of type:INT description:Identifier for the product in inventory.,column name:quantity_available of type:INT description:Quantity of the product available in inventory.,column name:reorder_level of type:INT description:Minimum quantity before a reorder is necessary.,column name:last_restocked of type:DATETIME description:Date and time when the product was last restocked.)
# 2024-08-13 08:39:04,858 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# INFO:sqlalchemy.engine.Engine:SELECT DATABASE()
# 2024-08-13 08:39:04,859 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-13 08:39:04,861 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# INFO:sqlalchemy.engine.Engine:SELECT @@sql_mode
# 2024-08-13 08:39:04,861 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-13 08:39:04,861 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# INFO:sqlalchemy.engine.Engine:SELECT @@lower_case_table_names
# 2024-08-13 08:39:04,861 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# INFO:root:creating ddl for table table name:customers table description:Stores information about customers of the online pharmacy. table columns:(column name:customer_id of type:INT description:Unique identifier for each customer.,column name:first_name of type:VARCHAR(50) description:First name of the customer.,column name:last_name of type:VARCHAR(50) description:Last name of the customer.,column name:email of type:VARCHAR(100) description:Email address of the customer.,column name:phone_number of type:VARCHAR(15) description:Contact phone number of the customer.,column name:address of type:VARCHAR(255) description:Shipping address of the customer.)
# 2024-08-13 08:39:04,861 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-13 08:39:04,867 INFO sqlalchemy.engine.Engine create table customers (customer_id INT,first_name VARCHAR(50),last_name VARCHAR(50),email VARCHAR(100),phone_number VARCHAR(15),address VARCHAR(255))
# INFO:sqlalchemy.engine.Engine:create table customers (customer_id INT,first_name VARCHAR(50),last_name VARCHAR(50),email VARCHAR(100),phone_number VARCHAR(15),address VARCHAR(255))
# 2024-08-13 08:39:04,867 INFO sqlalchemy.engine.Engine [generated in 0.00171s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00171s] {}
# INFO:root:creating ddl for table table name:products table description:Stores information about products available in the pharmacy. table columns:(column name:product_id of type:INT description:Unique identifier for each product.,column name:product_name of type:VARCHAR(100) description:Name of the product.,column name:description of type:TEXT description:Description of the product.,column name:price of type:DECIMAL(10, 2) description:Price of the product.,column name:stock_quantity of type:INT description:Quantity of the product available in stock.)
# 2024-08-13 08:39:07,017 INFO sqlalchemy.engine.Engine create table products (product_id INT,product_name VARCHAR(100),description TEXT,price DECIMAL(10, 2),stock_quantity INT)
# INFO:sqlalchemy.engine.Engine:create table products (product_id INT,product_name VARCHAR(100),description TEXT,price DECIMAL(10, 2),stock_quantity INT)
# 2024-08-13 08:39:07,017 INFO sqlalchemy.engine.Engine [generated in 0.00115s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00115s] {}
# INFO:root:creating ddl for table table name:orders table description:Stores information about customer orders. table columns:(column name:order_id of type:INT description:Unique identifier for each order.,column name:customer_id of type:INT description:Identifier for the customer who placed the order.,column name:order_date of type:DATETIME description:Date and time when the order was placed.,column name:total_amount of type:DECIMAL(10, 2) description:Total amount for the order.,column name:status of type:VARCHAR(20) description:Current status of the order (e.g., Pending, Shipped, Delivered).)
# 2024-08-13 08:39:08,562 INFO sqlalchemy.engine.Engine create table orders (order_id INT,customer_id INT,order_date DATETIME,total_amount DECIMAL(10, 2),status VARCHAR(20))
# INFO:sqlalchemy.engine.Engine:create table orders (order_id INT,customer_id INT,order_date DATETIME,total_amount DECIMAL(10, 2),status VARCHAR(20))
# 2024-08-13 08:39:08,562 INFO sqlalchemy.engine.Engine [generated in 0.00101s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00101s] {}
# INFO:root:creating ddl for table table name:order_items table description:Stores information about items in each order. table columns:(column name:order_item_id of type:INT description:Unique identifier for each order item.,column name:order_id of type:INT description:Identifier for the order to which this item belongs.,column name:product_id of type:INT description:Identifier for the product being ordered.,column name:quantity of type:INT description:Quantity of the product ordered.,column name:price of type:DECIMAL(10, 2) description:Price of the product at the time of order.)
# 2024-08-13 08:39:09,630 INFO sqlalchemy.engine.Engine create table order_items (order_item_id INT,order_id INT,product_id INT,quantity INT,price DECIMAL(10, 2))
# INFO:sqlalchemy.engine.Engine:create table order_items (order_item_id INT,order_id INT,product_id INT,quantity INT,price DECIMAL(10, 2))
# 2024-08-13 08:39:09,630 INFO sqlalchemy.engine.Engine [generated in 0.00136s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00136s] {}
# INFO:root:creating ddl for table table name:inventory table description:Stores information about inventory levels for products. table columns:(column name:inventory_id of type:INT description:Unique identifier for each inventory record.,column name:product_id of type:INT description:Identifier for the product in inventory.,column name:quantity_available of type:INT description:Quantity of the product available in inventory.,column name:reorder_level of type:INT description:Minimum quantity before a reorder is necessary.,column name:last_restocked of type:DATETIME description:Date and time when the product was last restocked.)
# 2024-08-13 08:39:10,506 INFO sqlalchemy.engine.Engine create table inventory (inventory_id INT,product_id INT,quantity_available INT,reorder_level INT,last_restocked DATETIME)
# INFO:sqlalchemy.engine.Engine:create table inventory (inventory_id INT,product_id INT,quantity_available INT,reorder_level INT,last_restocked DATETIME)
# 2024-08-13 08:39:10,507 INFO sqlalchemy.engine.Engine [generated in 0.00114s] {}
# INFO:sqlalchemy.engine.Engine:[generated in 0.00114s] {}
# 2024-08-13 08:39:11,358 INFO sqlalchemy.engine.Engine COMMIT
# INFO:sqlalchemy.engine.Engine:COMMIT

# %%
from dataSource import DataSource
DataSource().connect("acmepharm").fetch_columns("customers")
# Out:
# 2024-08-13 08:39:11,732 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# INFO:sqlalchemy.engine.Engine:SELECT DATABASE()
# 2024-08-13 08:39:11,732 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-13 08:39:11,732 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# INFO:sqlalchemy.engine.Engine:SELECT @@sql_mode
# 2024-08-13 08:39:11,736 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-13 08:39:11,736 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# INFO:sqlalchemy.engine.Engine:SELECT @@lower_case_table_names
# 2024-08-13 08:39:11,736 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-13 08:39:11,736 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# INFO:sqlalchemy.engine.Engine:BEGIN (implicit)
# 2024-08-13 08:39:11,736 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `customers`
# INFO:sqlalchemy.engine.Engine:SHOW CREATE TABLE `customers`
# 2024-08-13 08:39:11,736 INFO sqlalchemy.engine.Engine [raw sql] {}
# INFO:sqlalchemy.engine.Engine:[raw sql] {}
# 2024-08-13 08:39:11,736 INFO sqlalchemy.engine.Engine ROLLBACK
# INFO:sqlalchemy.engine.Engine:ROLLBACK
# [{'name': 'customer_id',
#   'type': INTEGER(),
#   'default': None,
#   'comment': None,
#   'nullable': True,
#   'autoincrement': False},
#  {'name': 'first_name',
#   'type': VARCHAR(length=50),
#   'default': None,
#   'comment': None,
#   'nullable': True},
#  {'name': 'last_name',
#   'type': VARCHAR(length=50),
#   'default': None,
#   'comment': None,
#   'nullable': True},
#  {'name': 'email',
#   'type': VARCHAR(length=100),
#   'default': None,
#   'comment': None,
#   'nullable': True},
#  {'name': 'phone_number',
#   'type': VARCHAR(length=15),
#   'default': None,
#   'comment': None,
#   'nullable': True},
#  {'name': 'address',
#   'type': VARCHAR(length=255),
#   'default': None,
#   'comment': None,
#   'nullable': True}]
