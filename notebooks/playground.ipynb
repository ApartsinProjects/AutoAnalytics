# %%
from mngDB import MngDB
user_uid='d2803e43-2d39-4586-8b70-d49052523902'
org_uid='57b5e8a2-5613-49ca-b1c2-1d2a9a4d28e1'

# %%
from dataSource import DataSource
ds=DataSource().connect_str("mysql+pymysql://taskanalytics:leningrad@localhost/atherosclerosis")
# Out:
# 2024-08-19 13:28:09,873 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2024-08-19 13:28:09,878 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-08-19 13:28:09,880 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2024-08-19 13:28:09,880 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-08-19 13:28:09,880 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2024-08-19 13:28:09,880 INFO sqlalchemy.engine.Engine [raw sql] {}
